# %%
import os

# %%
dir = '/home/thinking/raw/SAIHdatasActualizados/piezometros/'
locdir = os.listdir(dir)
for loc in locdir:
    if 'txt' in loc:
        continue
    locfiles = os.listdir(dir+loc)
    for files in locfiles:
        if 'from_parquet' in files:
            print(dir+loc+'/'+files)
            os.remove(dir+loc+'/'+files)
# Out:
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z06-Sondeo06/06Z06E12-Total solido disuelto (TDS)from_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z06-Sondeo06/06Z06E03-Conductividadfrom_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z06-Sondeo06/06Z06E10-Piezometricofrom_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z06-Sondeo06/06Z06E11-Salinidadfrom_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z06-Sondeo06/06Z06E01-Temperaturafrom_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z16-Sondeo16/06Z16E03-Conductividadfrom_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z16-Sondeo16/06Z16E12-Total solido disuelto (TDS)from_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z16-Sondeo16/06Z16E01-Temperaturafrom_parquet.csv
# /home/thinking/raw/SAIHdatasActualizados/piezometros/06Z16-Sondeo16/06Z16E11-Salinidadfrom_parquet.csv
# ...
