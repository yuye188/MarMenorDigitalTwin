# %% [markdown]
# # Script que crea las entidades NGSI-LD de Orion y sube los históricos a Timescale

# %% [markdown]
# ## Funciones empleadas para subir y modificar datos

# %%
# !pip install pyarrow
import pickle
# Out:
# Requirement already satisfied: pyarrow in c:\users\marie\appdata\local\programs\python\python311\lib\site-packages (15.0.0)
# Requirement already satisfied: numpy<2,>=1.16.6 in c:\users\marie\appdata\local\programs\python\python311\lib\site-packages (from pyarrow) (1.24.4)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle

# %% [markdown]
# ### Creación de una rambla en Orion Context Broker

# %%
import requests
import json
import math

def crear_rambla(id, dateLastValueReported, description, locality, postalCode, source, location, 
                 section, nextSection, previousSection, name, isPartOf):
    rambla_content = {
        "id": f"urn:ngsi-ld:Ravine:{id}",
        "identifier":{
            "type": "Property",
            "value": f"Ravine:{id}"
        },
        "type": "Ravine",
        "description": {
            "type": "Property",
            "value": description
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode,
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }

    # Función auxiliar para agregar una propiedad si no es None
    def add_property_if_not_none(property_name, value):
            
        if isinstance(value, str):
            rambla_content[property_name] = {
                "type": "Relationship",
                "object": value
            }
        elif value is not None:
            rambla_content[property_name] = {
                "value": value
            }        

    # Agregar propiedades si no son None
    add_property_if_not_none("nextSection", nextSection)
    add_property_if_not_none("previousSection", previousSection)
    add_property_if_not_none("section", section)
    add_property_if_not_none("isPartOf", isPartOf)

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }
    
    response = requests.post(url, headers=headers, json=rambla_content)

# %% [markdown]
# ### Creación de un Dispositivo en Orion Context Broker

# %%
def crear_device(id, alternateName, controlled_entity, controlled_properties, description, postalCode, locality, location, name, source, dateLastValueReported):
    device_content = {
        "id": f"urn:ngsi-ld:Device:{id}",
        "alternateName": {
            "type": "Property",
            "value": alternateName
        },
        "areaServed": {
            "type": "Property",
            "value": "Mar Menor"
        },
        "type": "Device",
        "controlledAsset" : {
            "type": "Relationship",
            "object": [
                controlled_entity
            ]
        },
        "controlledProperty": {
            "type": "Property",
            "value": controlled_properties
        },
        "dateLastValueReported": {
            "type": "Property",
            "value": dateLastValueReported
        },
        "description": {
            "type": "Property",
            "value": description
        },
        "deviceCategory": {
            "type": "Property",
            "value": [
                "sensor"
            ]
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }
    response = requests.post(url, headers=headers, json=device_content)
    print("Device")
    print(device_content)
    print(response.status_code)

# %% [markdown]
# ### Creación de una Medición de un Dispositivo

# %%
def crear_device_measurement(id, deviceType, value, controlledProperty, observedAt, depth, target , refDevice, unitCode, name, source, dateLastValueReported):
    device_measure_content = {
        "id": f"urn:ngsi-ld:DeviceMeasurement:{id}",
        "deviceType": {
            "type": "Property",
            "value": deviceType
        },
        "type": "DeviceMeasurement",
        "controlledProperty": {
            "type": "Property",
            "value": controlledProperty
        },
        "dateLastValueReported": {
            "type": "Property",
            "value": dateLastValueReported
        },
        "numValue":{
            "type": "Property",
            "value": value,
            "observedAt" : observedAt,
        },
        "refDevice": {
            "type": "Relationship",
            "object": f"urn:ngsi-ld:Device:{refDevice}",
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }

    if unitCode is not None:
        device_measure_content["unit"] = {
            "type": "Property",
            "value": unitCode
        }
    
    if math.isnan(value):
        device_measure_content["numValue"]["value"] = -99

    if depth is not None:
        device_measure_content["depth"] = {
            "type": "Property",
            "value": depth
        }

    if target is not None:
        device_measure_content["target"] = {
            "type": "Property",
            "value": target
        }


    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }
    print("DeviceMeasurement")
    print(device_measure_content)
    
    response = requests.post(url, headers=headers, json=device_measure_content)
    print(response.status_code)

# %% [markdown]
# ### Creación de una red acuatica, que estara compuesta por un complejo de rambas, como la del Albujón

# %%
def crear_water_network(id, isComposedOf, description, name, location = [[[37.7138,-1.1874], [37.7157, -0.8588], [37.7646, -1.1439], [37.7138,-1.1874]]]):
    water_network_content = {
        "id": f"urn:ngsi-ld:WaterNetwork:{id}",
        "type": "WaterNetwork",
        "isComposedOf": isComposedOf,
        "description": {
            "type": "Property",
            "value": description
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Polygon",
                "coordinates": location
            }
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia"
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }
    response = requests.post(url, headers=headers, json=water_network_content)
    print("WaterNetwork")
    print(response.status_code)

# %% [markdown]
# ### Creación de una red piezometrica a la que asociaremos diversos sondeos

# %%
def crear_piezometric_net(id, description, name, source = "http://155.54.95.167/" , location = [[[37.6410,-0.7628], [37.7171, -0.8621], [37.8293,-0.7844], [37.8367, -0.8037], [37.7225, -0.9086], [37.6178, -0.7755], [37.6410,-0.7628] ]]):
    water_network_content = {
        "id": f"urn:ngsi-ld:PiezometricNet:{id}",
        "identifier": {
            "type": "Property",
            "value": f"urn:ngsi-ld:PiezometricNet:{id}"
        },
        "type": "PiezometricNet",
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia"
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "description": {
            "type": "Property",
            "value": description
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Polygon",
                "coordinates": location
            }
        },
        "name" : {
            "type": "Property",
            "value": name
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }
    response = requests.post(url, headers=headers, json=water_network_content)
    print("PiezometricNet")
    print(response.status_code)

# %% [markdown]
# ### Creación de un Sondeo, el cual pertenecera a una red piezometrica

# %%
import math

def crear_sounding(id, locality, postalCode, location, description, source, dateLastValueReported, numberInNetwork, name, isPartOf):

    piezometer_content = {
        "id": f"urn:ngsi-ld:SoundingPlace:{id}",
        "identifier":{
            "type": "Property",
            "value": f"SoundingPlace:{id}"
        },
        "type": "SoundingPlace",
        "category": {
            "type": "Property",
            "value": "sensor"
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode
            },
            "verified": {
                "type": "Property",
                "value": True
            }
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "description": {
            "type": "Property",
            "value": description
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "numberInNetwork": {
            "type": "Property",
            "value": numberInNetwork
        },
         "name": {
            "type": "Property",
            "value": name
        },
        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }

    if isPartOf is not None:
        piezometer_content["isPartOf"] = {
            "type": "Relationship",
            "object": isPartOf
        }

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }


    response = requests.post(url, headers=headers, json=piezometer_content)
    print(piezometer_content)
    print(response)

# %% [markdown]
# ### Creación de una Boya

# %%
import requests
import json

def crear_boya(id, dateLastValueReported, description, postalCode, locality, location, name, source, closeMeasurements=None):
    buoy_content = {
        "id": f"urn:ngsi-ld:Buoy:{id}",
        "identifier":{
            "type": "Property",
            "value":  f"Buoy:{id}"
        },
        "type": "Buoy",
        "description": {
            "type": "Property",
            "value": description
        },
        "address": {
            "type": "Property",
            "value": {
                "addressCountry": "ES",
                "addressRegion": "Murcia",
                "addressLocality": locality,
                "postalCode": postalCode
            },
        },
        "location": {
            "type": "GeoProperty",
            "value": {
                "type": "Point",
                "coordinates": location
            }
        },
        "name": {
            "type": "Property",
            "value": name
        },
        "source": {
            "type": "Property",
            "value": source
        },
        "closeMeasurements": closeMeasurements,

        "@context": "https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld"
    }
    
    if closeMeasurements is None:
        del buoy_content["closeMeasurements"]

    url = "http://localhost:1026/ngsi-ld/v1/entities/"

    headers = {
        "Content-Type": "application/ld+json"
    }

    try:
        response = requests.post(url, headers=headers, json=buoy_content)
        response.raise_for_status()  # Lanza una excepción para códigos de estado HTTP no exitosos
    except requests.exceptions.RequestException as e:
        print(f"Error creating entity: {e}")

# %% [markdown]
# ### Modificación de una entidad, principalmente usado para el DeviceMeasurement con numValue

# %% [markdown]
# Tambien se emplea para modificar el isComposedOf del WaterNetwork

# %%
def modify_entity( value, observedAt, unitcode, url, depth = None, place = None, isComposedOf = False):

    headers = {
        'Content-Type': 'application/json',
        'Link': '<https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

    if isinstance(value, float) and  math.isnan(value):
        value = -99

    modify_content = {
        "numValue": {
            "type": "Property",
            "value": value,
            "observedAt": observedAt
        },
        "dateLastValueReported": {
            "type": "Property",
            "value": observedAt
        }
    }

    if depth is not None:
        modify_content["numValue"]["depth"] = {
            "type": "Property",
            "value": depth
        }
    
    if place is not None:
        modify_content["numValue"]["measurementPlace"] = {
            "type": "Property",
            "value": place
        }

    if unitcode is not None:
        modify_content["numValue"]["unitCode"] = unitcode

    if isComposedOf:
        modify_content = {
            "isComposedOf": value
        }


    print("modify_content")
    print(modify_content)
    response = requests.patch(url, headers=headers, json=modify_content)
    print(response.status_code)
    try:
        if response.status_code != 204:
            print(response.text)
    finally:
        response.close()

# %% [markdown]
# ### Función empleada para añadir atributos a una entidad

# %%
def create_attribute(newAttributeName, value, observedAt, url, multipleValue = None):

    headers = {
        'Content-Type': 'application/json',
        'Link': '<https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

    if multipleValue is not None:
        modify_content = {
            newAttributeName: {
                 "value": [multipleValue]
            }
        }
    elif observedAt is None:
        modify_content = {
            newAttributeName: {
                "value": value
            }
        }
    else:       
        modify_content = {
            newAttributeName: {
                "value": value,
                "observedAt": observedAt
            }
        }

    response = requests.post(url, headers=headers, json=modify_content)
    try:
        if response.status_code != 204:
            print(response.text)
    finally:
        response.close()

# %% [markdown]
# ### Función que realiza una petición para buscar las entidades cercanas a una entidad basado en sus coordenadas

# %%
def search_close_entities(coordinate_lat,coordinate_long, id_entity):
    url = 'http://localhost:1026/ngsi-ld/v1/entities'
    headers = {
        'Accept': 'application/json',
        'Link': '<https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld>; rel="http://www.w3.org/ns/json-ld#context"; type="application/ld+json"'
    }

    params = {
        'geometry': 'Point',
        'coordinates': f'[{coordinate_lat},{coordinate_long}]',
        'georel': 'near;maxDistance==4000',
        'options': 'keyValues',
    }

    response = requests.get(url, headers=headers, params=params)

    data = response.json()

    filtered_data = [entity.get("id",) for entity in data if (id_entity not in entity.get('id', '') )]
    
    filtered_data = [ entity for entity in filtered_data if "Buoy" in entity or "SoundingPlace" in entity or "Ravine" in entity] 

    return filtered_data

# %% [markdown]
# ## Codigo para la subida de los datos

# %% [markdown]
# ### Subida datos Boyas

# %% [markdown]
# Creamos un diccionario donde almacenaremos el id de las entidades y sus coordenadas para buscar posteriormente sus entidades cercanas y otras utilidades

# %%
entities_id = {}

# %% [markdown]
# #### Información estática de las Boyas que emplearemos para crearlas.

# %% [markdown]
# En caso de añadir nuevas ramblas habrá que añadirlas a este diccionario

# %%
diccionario_info_boyas = {
    "E1": {
        "locality": "Mar Menor, San Javier, Cartagena",
        "postalCode": "30380",
        "location": [37.81, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E1",
    },
    "E2": {
        "locality": "Mar Menor, Playa de la Hita, Cartagena",
        "postalCode": "30380",
        "location": [37.76, -0.8],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E2",
    },
    "E3": {
        "locality": "Mar Menor, Playa de la Hita, Cartagena",
        "postalCode": "30380",
        "location": [37.76, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3",
    },
    "E4": {
        "locality": "Mar Menor, La Manga, Cartagena",
        "postalCode": "30380",
        "location": [37.74, -0.74],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E4",
    },
    "E5": {
        "locality": "Mar Menor, La Manga, Cartagena",
        "postalCode": "30380",
        "location": [37.74, -0.72],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E5",
    },
    "E6": {
        "locality": "Mar Menor, Isla Mayor, Cartagena",
        "postalCode": "30720",
        "location": [37.71, -0.77],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E6",
    },
    "E7": {
        "locality": "Mar Menor, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.71, -0.83],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E7",
    },
    "E8": {
        "locality": "Mar Menor, Los Urrutias, Cartagena",
        "postalCode": "30368",
        "location": [37.69, -0.81],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E8",
    },
    "E9": {
        "locality": "Mar Menor, Saladar de Lo Poyo, Cartagena",
        "postalCode": "30368",
        "location": [37.66, -0.8],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E9",
    },
    "E10": {
        "locality": "Mar Menor, Los Nietos, Cartagena",
        "postalCode": "30383",
        "location": [37.65, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E10",
    },
    "E11": {
        "locality": "Mar Menor, La Manga, Cartagena",
        "postalCode": "30380",
        "location": [37.65, -0.72],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E11",
    },
    "E12": {
        "locality": "Mar Menor, Cartagena",
        "postalCode": "30380",
        "location": [37.68, -0.78],
        "unitCode": "MTR",
        "source": "https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E12",
    },
}

# %% [markdown]
# #### Lectura de los .csv y unión de estos

# %%
import os
import glob
import pandas as pd
import time

# Especifica la ruta de la carpeta principal
carpeta = "/home/thinking/raw/BoyasProf/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}

# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    print(carpeta_actual)
    df_total = pd.DataFrame()
    archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))
    for archivo in archivos_csv:
        
        nombre_archivo = archivo.split("/")[-1].split(".")[0]
        df_temporal = pd.read_csv(archivo)
        df_temporal.columns = [df_temporal.columns[0]] + [f"{nombre_archivo}_{col.split('_')[1]}" for col in df_temporal.columns[1:]]
        df_temporal = df_temporal.loc[:, ~df_temporal.columns.str.contains("None")]
        df_temporal.rename(columns={'fecha': 'Date'}, inplace=True)
        
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="outer")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")
# Out:
# CTD-E3
# CTD-E12
# CTD-E11
# CTD-E10
# CTD-E9
# CTD-E4
# CTD-E1
# CTD-E7
# CTD-E8
# CTD-E6
# CTD-E5
# CTD-E2

# %% [markdown]
# #### Codigo de creación de las entidades actuales en el Orion Context

# %% [markdown]
# En este codigo se crean las entidades en el Orion Context Broker (OCB) y se realizan un par de modificaciones, las cuales al realizarse Mintaka se encargara de almacenar los cambios en el Timescale-DB (base de datos temporal). Simplemente realizaremos un par de modificaciones para que se creen los schemas en Timescale.

# %%
import math
import time
import re

# Diccionario que asocia las columnas del csv con el nombre del sensor que le asociemos
maper_property_sensor = { "Clorofila":"ChlorophyllSensor","PH":"PhSensor","Polietileno":"PolyethyleneSensor","Turbidez":"TurbiditySensor","Salinidad":"SalinitySensor",
        "Transparencia":"TransparencySensor","Oxigeno":"OxygenSensor","Temperatura": "TemperatureSensor", "Conductividad": "ConductivitySensor", "Piezometrico":"PiezometricLevelSensor", 
        "Total solido disuelto (TDS)": "TdsSensor", "Materia Organiza":"OrganicMatterSensor"
}

# Diccionario que asocia las columnas del csv con el nombre de la propiedad controlada que hayamos indicado en el modelo .yaml
maper_property_controlled = { "Temperatura": "temperature","Materia Organiza":"OrganicMatterSensor", "Conductividad": "conductivity", "Piezometrico":"piezometricLevel", "Salinidad":"salinity",
       "Total solido disuelto (TDS)": "tds", "Clorofila":"chlorophyll","PH":"pH","Polietileno":"polyethylene","Turbidez":"turbidity","Transparencia":"transparency","Oxigeno":"oxygen"
}

# Diccionario que asocia las columnas del csv con el nombre de la unidad de medida que le asociemos
maper_property_unitcode = { "Temperatura": "CEL", "Conductividad": "microseconds/cm", "Piezometrico":"msnm", "Salinidad":"PSU",
       "Total solido disuelto (TDS)": "mg/l", "Materia Organiza":None,"Clorofila":None,"PH":"pH",
       "Polietileno":None,"Turbidez":"NTU","Transparencia":None,"Oxigeno":None
}

# Diccionario que asocia el ID de un DeviceMeasurement con el ID de una entidad y 
# el nombre de la propiedad controlada que mide
# Con este diccionario podremos realizar posteriormente la modificación de las entidades
link_boya_sensores = {}

# Diccionario en el que se almacenarán las entidades de las boyas asociadas a cada carpeta
boya_entity = {}

# Contador que indica el numero de Boyas y Devices que se han creado
num_boyas = 0
num_devices = 0

# Contador que indica el numero de dispositivo de mediciones que se han creado
counter_device_measurements = 0

# Recorremos por cada Boya
for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    # Obtenemos los nombres de las columnas del csv
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    
    # Obtenemos el ID de la boya a partir del nombre de la carpeta 
    id_boya = carpeta.split("-")[1]
    # Creamos los ID de las entidades y dispositivo
    number_entity = str(num_boyas).zfill(3)
    number_device = str(num_devices).zfill(3)
    id_entity = f"urn:ngsi-ld:Buoy:{number_entity}"

    boya_entity[carpeta] = id_entity
    
    # Obtenemos las propiedades controladas por el dispositivo
    controlled_properties = [maper_property_controlled[valor] for valor in sensores if valor != "Date"]

    # Creamos el dispositivo
    crear_device(
        id=number_device,
        alternateName = "Device" + number_device + " for Buoy "+ number_entity,
        controlled_entity = id_entity,
        controlled_properties = controlled_properties,
        description = "Buoy "+ id_boya +" for measuring water quality in Mar Menor",
        postalCode = diccionario_info_boyas[id_boya]["postalCode"],
        locality = diccionario_info_boyas[id_boya]["locality"],
        location = diccionario_info_boyas[id_boya]["location"],
        name = "Buoy " + id_boya+" found in Mar Menor",
        source = diccionario_info_boyas[id_boya]["source"],
        dateLastValueReported=valorCarpeta["Date"].iloc[len(valorCarpeta)-1]
    )
    
    # Recorremos por cada fila del csv
    for index, row in valorCarpeta.iterrows():
        # Primera fila del csv
        if index == 0:
            # Recorremos por cada sensor
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
                
                # Recorremos todas las columnas que empiecen por ese sensor ya que en los csv hay varias segun la profundidad
                for columnName in [ col for col in valorCarpeta.columns if col.startswith(valorSensor)]:
                    depth = columnName.split("_")[1]
                    depth = float(depth)

                    # Creamos el ID del device measurement y la entidad
                    id_device_measurement = f"urn:ngsi-ld:DeviceMeasurement:{str(counter_device_measurements).zfill(3)}"

                    crear_device_measurement(
                        id=str(counter_device_measurements).zfill(3),
                        deviceType=maper_property_sensor[sensores[contador]],
                        value=row[columnName],
                        controlledProperty=maper_property_controlled[valorSensor],
                        observedAt=row["Date"],
                        depth=depth,
                        target=None,
                        refDevice=number_device,
                        unitCode=maper_property_unitcode[valorSensor],
                        name="DeviceMeasurement "+ str(counter_device_measurements).zfill(3),
                        source=diccionario_info_boyas[id_boya]["source"],
                        dateLastValueReported=row["Date"]
                    )
                    counter_device_measurements = counter_device_measurements + 1
                    
                    # Asociamos el id del device measurement con el id de la entidad y el nombre de la propiedad controlada
                    if id_entity not in link_boya_sensores:
                        link_boya_sensores[id_entity] = {}
                    if valorSensor not in link_boya_sensores[id_entity]:
                        link_boya_sensores[id_entity][valorSensor] = []
                    link_boya_sensores[id_entity][valorSensor].append(id_device_measurement),
                
            # Creamos la boya
            entities_id[id_entity] = diccionario_info_boyas[id_boya]["location"]
            crear_boya(
                id=number_entity,
                dateLastValueReported=row["Date"],
                description="Buoy "+ id_boya +" for measuring water quality in the Mar Menor",
                postalCode=diccionario_info_boyas[id_boya]["postalCode"],
                location=diccionario_info_boyas[id_boya]["location"],
                locality=diccionario_info_boyas[id_boya]["locality"],
                name="Buoy " + id_boya,
                source=diccionario_info_boyas[id_boya]["source"]
            )
            num_boyas += 1
        
        # si el indice es 1 entonces haremos la modificación de las entidades
        elif index == 1:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
                
                # recorremos por cada propiedad y profundidad
                for number, columnName in enumerate([ col for col in valorCarpeta.columns if col.startswith(valorSensor)]):
                    depth = columnName.split("_")[1]
                    depth = float(depth)
                    
                    # recuperamos el id del device measurement a partir de la entidad y el nombre de la propiedad controlada
                    id_device_measurement = link_boya_sensores[id_entity][valorSensor][number]

                    # modificamos la entidad
                    modify_entity(
                        value=row[columnName],
                        observedAt=row["Date"],
                        unitcode=maper_property_unitcode[valorSensor],
                        url="http://localhost:1026/ngsi-ld/v1/entities/"+id_device_measurement+"/attrs",
                    )
            # 1 segundo para no saturar la red 
            time.sleep(1)
        else:
            break
    num_devices = num_devices+1

with open('./variables_entidades/boya_entity.pkl', 'wb') as f:
    pickle.dump(boya_entity, f)
with open('./variables_entidades/link_boya_sensores.pkl', 'wb') as f:
    pickle.dump(link_boya_sensores, f)
# Out:
# CTD-E3
# Device
# {'id': 'urn:ngsi-ld:Device:000', 'alternateName': {'type': 'Property', 'value': 'Device000 for Buoy 000'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Buoy:000']}, 'controlledProperty': {'type': 'Property', 'value': ['conductivity', 'transparency', 'pH', 'polyethylene', 'oxygen', 'temperature', 'turbidity', 'OrganicMatterSensor', 'chlorophyll', 'salinity']}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}, 'description': {'type': 'Property', 'value': 'Buoy E3 for measuring water quality in Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Mar Menor, Playa de la Hita, Cartagena', 'postalCode': '30380'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.76, -0.78]}}, 'name': {'type': 'Property', 'value': 'Buoy E3 found in Mar Menor'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:000', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 7.21, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 000'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': 0.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:001', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 7.18, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 001'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:002', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 7.2, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 002'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -2.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:003', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 003'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -3.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:004', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 004'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -4.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:005', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 005'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.6666666666666666}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:006', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 006'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.3333333333333333}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:007', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 007'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -5.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:008', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 008'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -6.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:009', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 009'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.3333333333333333}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:010', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 010'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.6666666666666665}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:011', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 011'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.4}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:012', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 012'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.8}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:013', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 013'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.2000000000000002}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:014', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 014'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.6}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:015', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 015'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.2857142857142857}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:016', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 016'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.5714285714285714}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:017', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 017'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -0.8571428571428571}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:018', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 018'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.1428571428571428}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:019', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 019'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.4285714285714284}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:020', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 020'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}, 'depth': {'type': 'Property', 'value': -1.7142857142857142}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:021', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 021'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': 0.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:022', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 022'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:023', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 023'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -2.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:024', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 024'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -3.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:025', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 025'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -4.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:026', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 026'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.6666666666666666}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:027', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 027'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.3333333333333333}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:028', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 028'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -5.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:029', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 029'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -6.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:030', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 030'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.3333333333333333}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:031', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 031'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.6666666666666665}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:032', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 032'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.4}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:033', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 033'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.8}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:034', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 034'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.2000000000000002}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:035', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 035'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.6}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:036', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 036'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.2857142857142857}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:037', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 037'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.5714285714285714}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:038', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 038'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -0.8571428571428571}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:039', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 039'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.1428571428571428}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:040', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 040'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.4285714285714284}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:041', 'deviceType': {'type': 'Property', 'value': 'TransparencySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'transparency'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 041'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'depth': {'type': 'Property', 'value': -1.7142857142857142}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:042', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 042'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': 0.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:043', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 043'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -1.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:044', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 044'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -2.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:045', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 045'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -3.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:046', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 046'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -4.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:047', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 047'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -0.6666666666666666}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:048', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 048'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -1.3333333333333333}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:049', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 049'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -5.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:050', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 050'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -6.0}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:051', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 051'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -0.3333333333333333}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:052', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 052'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -1.6666666666666665}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:053', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 053'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -0.4}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:054', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 054'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -0.8}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:055', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 055'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -1.2000000000000002}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:056', 'deviceType': {'type': 'Property', 'value': 'PhSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-02T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-02T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:000'}, 'source': {'type': 'Property', 'value': 'https://idearm.imida.es/cgi/siomctdmarmenor/#CTD-E3'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 056'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'pH'}, 'depth': {'type': 'Property', 'value': -1.6}}
# 201
# DeviceMeasurement
# ...
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.34, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.94, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.35, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 28.53, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 28.56, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 28.87, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.39, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.48, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.94, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 12.1, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 12.09, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 10.63, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 45.6, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 45.59, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 45.49, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-08-04T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-08-04T00:00:00Z'}}
# 204

# %% [markdown]
# #### Conexión directa con Timescale para subir los datos sin pasar por ORION

# %% [markdown]
# Aqui subiremos los datos históricos sin pasar por ORION, ya que ORION solo le importan los datos actuales y asi se agiliza enormemente el proceso

# %%
import psycopg2
from datetime import datetime
import uuid
# Conectarse a la base de datos
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="orion",
    user="orion",
    password="orion"
)

cursor = conn.cursor()
datos_a_insertar = []

# Recorremos las distintas Boyas
for carpeta, valorCarpeta in dfs.items():
    # Obtenemos el ID de la boya a partir del nombre de la carpeta
    id_entity = boya_entity[carpeta]
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    # Recorremos por cada fila del csv
    for index, row in valorCarpeta.iterrows():
        if index == len(valorCarpeta)-1 or index == 0 or index == 1:
            continue
        # Para cada columna del csv
        for contador,valorSensor in enumerate(sensores):
            if valorSensor == "Date":
                continue
            
            # Recorremos todas las columnas que empiecen por ese sensor ya que en los csv hay varias segun la profundidad
            for number, columnName in enumerate([ col for col in valorCarpeta.columns if col.startswith(valorSensor)]):
                depth = columnName.split("_")[1]
                depth = float(depth)
                
                # Recuperamos el ID del device measurement a partir de la entidad y el nombre de la propiedad controlada
                id_device_measurement = link_boya_sensores[id_entity][valorSensor][number]

                fecha_hora = datetime.strptime(row["Date"], "%Y-%m-%dT%H:%M:%SZ")
                
                value = row[columnName]
                if math.isnan(row[columnName]):
                    value = -99

                # Almacenamos en una variable los datos que vamos a insertar habiendonos fijado en el esquema de la base de datos
                datos_a_insertar.append(
                    (f'urn:ngsi-ld:attribute:{uuid.uuid4()}', 'https://smartdatamodels.org/dataModel.DeviceMeasurement/numValue', 'Replace', id_device_measurement, fecha_hora, True, maper_property_unitcode[valorSensor], 'None', 'Number', None, None, value, None, None, None, None, None, None, None, None, datetime.now())
                )
                
                # En vez de insertar los datos en la base de datos cada vez que se recorre una fila del csv,
                # se almacenan en una lista y se insertan en la base de datos cuando la lista tiene más de 100000 filas
                if len(datos_a_insertar) > 100000:
                    consulta_insercion = f"INSERT INTO attributes VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
                    print(f"Insertando {len(datos_a_insertar)} filas en la tabla attributes")
                    try:
                        # Ejecutar la consulta para insertar los datos
                        cursor.executemany(consulta_insercion, datos_a_insertar)
                        conn.commit()
                        datos_a_insertar = []
                        print(f"Se han insertado {cursor.rowcount} filas en la tabla attributes")
                    except (Exception, psycopg2.DatabaseError) as error:
                        conn.rollback()
                    # Confirmar la transacción
                        print(f"Error: {error}")

# Insertar los datos restantes en la base de datos
if len(datos_a_insertar) > 0:
    consulta_insercion = f"INSERT INTO attributes VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    print(f"Insertando {len(datos_a_insertar)} filas en la tabla attributes")
    try:
        # Ejecutar la consulta para insertar los datos
        cursor.executemany(consulta_insercion, datos_a_insertar)
        conn.commit()
        datos_a_insertar = []
        print(f"Se han insertado {cursor.rowcount} filas en la tabla attributes")
    except (Exception, psycopg2.DatabaseError) as error:
        conn.rollback()
    # Confirmar la transacción
        print(f"Error: {error}")

                

# Cerrar el cursor y la conexión
cursor.close()
conn.close()
# Out:
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 22516 filas en la tabla attributes
# Se han insertado 22516 filas en la tabla attributes

# %% [markdown]
# #### Queda actualizar las entidades de ORION con los ultimos valores

# %%
for carpeta, valorCarpeta in dfs.items():
    # Obtenemos los ultimos valores de cada columna del csv
    ultimos_valores = valorCarpeta.iloc[len(valorCarpeta)-1]
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    id_entity = boya_entity[carpeta]
    # Recorremos por cada columna del csv
    for contador,valorSensor in enumerate(sensores):
        if valorSensor == "Date":
            continue

        for number, columnName in enumerate([ col for col in valorCarpeta.columns if col.startswith(valorSensor)]):
            depth = columnName.split("_")[1]
            depth = float(depth)

            id_device_measurement = link_boya_sensores[id_entity][valorSensor][number]

            modify_entity(
                value=ultimos_valores[columnName],
                observedAt=ultimos_valores["Date"],
                unitcode=maper_property_unitcode[valorSensor],
                url="http://localhost:1026/ngsi-ld/v1/entities/"+id_device_measurement+"/attrs",
            )
# Out:
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.13, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.13, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.17, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.26, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.26, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.26, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.26, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 390.84, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 226.07, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 195.32, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 120.27, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 31.83, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.25, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.26, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.65, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.63, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.63, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.63, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.62, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 127.71, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 88.3, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 89.92, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 82.05, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 87.45, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 90.15, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 168.29, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.21, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.42, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.51, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.25, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.04, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.81, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.73, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.38, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.41, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.59, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.96, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.94, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.94, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.94, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.5, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.5, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.49, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.46, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.57, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.72, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.85, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.58, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.54, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.47, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.55, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.74, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.82, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 9.56, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.44, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.47, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.47, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.47, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.45, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.4, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.55, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.58, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.59, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.69, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.95, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 44.0, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 44.0, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 44.0, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.3, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.3, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.3, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.3, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.3, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.3, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 717.54, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 493.97, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 137.06, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 156.67, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 253.74, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 165.86, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.68, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.68, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.67, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.67, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.67, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.67, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# ...
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'pH'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 85.72, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 88.55, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 90.15, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 85.59, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 83.35, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 96.95, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.1, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.1, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.09, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.09, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.09, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.05, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 30.61, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.52, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.51, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.52, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.51, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.52, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.66, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'NTU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.6, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.62, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.59, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.59, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.62, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.6, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.4, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.41, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.41, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.41, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.42, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.71, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.9, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.9, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.9, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.9, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.9, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 43.9, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-08-24T00:00:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-08-24T00:00:00Z'}}
# 204

# %% [markdown]
# #### Codigo para obtener información del esquema y poder ver ejemplos

# %%
import psycopg2
import datetime
# Conectarse a la base de datos
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="orion",
    user="orion",
    password="orion"
)
cursor = conn.cursor()

cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")

# Iterar sobre las tablas
for tabla in cursor.fetchall():

    nombre_tabla = tabla[0]
    print(nombre_tabla)
    if nombre_tabla == "subattributes":
        print(f"Esquema de la tabla '{nombre_tabla}':")
        
        # Obtener información sobre las columnas de la tabla
        cursor.execute(f"SELECT column_name, data_type FROM information_schema.columns WHERE table_name = '{nombre_tabla}'")
        
        # Mostrar el esquema de la tabla
        for columna in cursor.fetchall():
            print(columna)

        cursor.execute(f"SELECT * FROM {nombre_tabla}")
        contador = 0
        # Mostrar el esquema de la tabla
        for columna in cursor.fetchall():
            contador += 1
            print(columna)
            if contador > 1500000:
                break
        #('urn:ngsi-ld:attribute:instance:df60ec4c-d714-11ee-aec1-0242ac120105', 'https://smartdatamodels.org/depth', 'urn:ngsi-ld:DeviceMeasurement:006', 'urn:ngsi-ld:attribute:instance:df60ec2e-d714-11ee-aec1-0242ac120105', 'None', None, None, 'String', '-1.6', None, None, None, None, None, None, None, None, None, None, datetime(2024, 2, 29, 15, 11, 54, 204000))


# Cerrar el cursor y la conexión
cursor.close()
conn.close()
# Out:
# spatial_ref_sys
# geography_columns
# geometry_columns
# raster_columns
# raster_overviews
# entities
# attributes
# subattributes
# Esquema de la tabla 'subattributes':
# ('instanceid', 'text')
# ('id', 'text')
# ('entityid', 'text')
# ('attrinstanceid', 'text')
# ('attrdatasetid', 'character varying')
# ('observedat', 'timestamp without time zone')
# ('unitcode', 'text')
# ('valuetype', 'USER-DEFINED')
# ('text', 'text')
# ('boolean', 'boolean')
# ('number', 'double precision')
# ('datetime', 'timestamp without time zone')
# ('compound', 'jsonb')
# ('geopoint', 'USER-DEFINED')
# ('geomultipoint', 'USER-DEFINED')
# ('geopolygon', 'USER-DEFINED')
# ('geomultipolygon', 'USER-DEFINED')
# ('geolinestring', 'USER-DEFINED')
# ('geomultilinestring', 'USER-DEFINED')
# ('ts', 'timestamp without time zone')
# ('urn:ngsi-ld:attribute:instance:5bab90a2-2839-11ef-85f7-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:000', 'urn:ngsi-ld:attribute:instance:5bab903e-2839-11ef-85f7-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 8, 341000))
# ('urn:ngsi-ld:attribute:instance:5fa96260-2839-11ef-a9cf-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:001', 'urn:ngsi-ld:attribute:instance:5fa961fc-2839-11ef-a9cf-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 15, 494000))
# ('urn:ngsi-ld:attribute:instance:61e122de-2839-11ef-8671-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:002', 'urn:ngsi-ld:attribute:instance:61e12284-2839-11ef-8671-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 19, 215000))
# ('urn:ngsi-ld:attribute:instance:639ea2fe-2839-11ef-b7f9-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:003', 'urn:ngsi-ld:attribute:instance:639ea2a4-2839-11ef-b7f9-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 22, 134000))
# ('urn:ngsi-ld:attribute:instance:666f4240-2839-11ef-b949-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:004', 'urn:ngsi-ld:attribute:instance:666f41e6-2839-11ef-b949-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 26, 857000))
# ('urn:ngsi-ld:attribute:instance:677e8984-2839-11ef-b736-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:005', 'urn:ngsi-ld:attribute:instance:677e8934-2839-11ef-b736-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 28, 635000))
# ('urn:ngsi-ld:attribute:instance:6a76386c-2839-11ef-9177-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:006', 'urn:ngsi-ld:attribute:instance:6a763808-2839-11ef-9177-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 33, 614000))
# ('urn:ngsi-ld:attribute:instance:6c15ff72-2839-11ef-b531-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:007', 'urn:ngsi-ld:attribute:instance:6c15ff18-2839-11ef-b531-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 36, 338000))
# ('urn:ngsi-ld:attribute:instance:6e166a1e-2839-11ef-9637-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:008', 'urn:ngsi-ld:attribute:instance:6e1669c4-2839-11ef-9637-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 39, 697000))
# ('urn:ngsi-ld:attribute:instance:708be9f4-2839-11ef-8b86-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:009', 'urn:ngsi-ld:attribute:instance:708be990-2839-11ef-8b86-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 43, 822000))
# ('urn:ngsi-ld:attribute:instance:735537d0-2839-11ef-8f49-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:010', 'urn:ngsi-ld:attribute:instance:73553776-2839-11ef-8f49-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 48, 497000))
# ('urn:ngsi-ld:attribute:instance:75eac24e-2839-11ef-8d04-0242ac120104', 'https://uri.etsi.org/ngsi-ld/default-context/verified', 'urn:ngsi-ld:Device:011', 'urn:ngsi-ld:attribute:instance:75eac118-2839-11ef-8d04-0242ac120104', 'None', None, None, 'Boolean', None, True, None, None, None, None, None, None, None, None, None, datetime.datetime(2024, 6, 11, 21, 27, 52, 832000))

# %% [markdown]
# #### Al haber tantos datos algunas consultas eran lentas por lo que se han creado Indices sobre los atributos mas empleados

# %%
import psycopg2
import datetime
# Conectarse a la base de datos
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="orion",
    user="orion",
    password="orion"
)

cur = conn.cursor()

# Crear índice en la columna 'datasetid'
cur.execute("CREATE INDEX idx_datasetid ON attributes (datasetid);")

# Crear índice en la columna 'entityid'
cur.execute("CREATE INDEX idx_entityid ON attributes (entityid);")

# Crear índice en la columna 'observedat'
cur.execute("CREATE INDEX idx_observedat ON attributes (observedat);")

# Confirmar los cambios
conn.commit()


# Cerrar el cursor y la conexión
cur.close()
conn.close()

# %% [markdown]
# ### Subimos informacion de los Piezometros

# %% [markdown]
# #### Lectura csv/parquet y los juntamos

# %%
import os
import glob
import pandas as pd
import pyarrow.parquet as pq


# Especifica la ruta de la carpeta principal
carpeta = "/home/thinking/raw/SAIHdatasActualizados/piezometros/"


# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}


# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    df_total = pd.DataFrame()
    archivos_parquet = glob.glob(os.path.join(carpeta+carpeta_actual, "*.parquet"))
    #archivos_csv = glob.glob(os.path.join(carpeta+carpeta_actual, "*.csv"))
    for archivo in archivos_parquet:
    
        #df_temporal = pd.read_csv(archivo)
        df_temporal = pd.read_parquet(archivo)
        df_temporal.to_csv(archivo.split(".")[0]+"from_parquet.csv", index=False)
        tabla = pq.ParquetFile(archivo)
        #pq.write_table(tabla, "ejemplo.parquet", version='1.0')
        # Imprime la versión del archivo Parquet
        print(tabla.metadata)
        print("-"*10)
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="outer")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")
# Out:
# <pyarrow._parquet.FileMetaData object at 0x7f0b80156fc0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 81492
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1685
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80157d80>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1565
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80156fc0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1561
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b802a4b30>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1537
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80149f30>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1557
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b801484f0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1560
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80156fc0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b788ed170>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1684
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b801febb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1537
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b79576250>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 79476
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1556
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b7ad33ce0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80148680>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b4163ffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b30f53b00>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b795762a0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b310abfb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b310abc40>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b78910310>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b25e40ae0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1544
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b22d47fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b789101d0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b78910180>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1571
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b22e8c0e0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b789101d0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1565
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b22d44310>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b4163ff60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b78910360>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1692
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b786dffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b8014abb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1544
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b311f3fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b13b13f10>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1544
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b13b13fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1692
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b13c2ffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b11497fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b09ccff10>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b114cffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1565
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b114cfc40>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b111f08b0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1571
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b311f3fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0796ffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b09f43fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b111f07c0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b017dbf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b261cbf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b311f3fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1693
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0aff40bf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1565
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0a30bf10>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1573
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0aff673e70>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b261cbf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b09f40770>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afceabf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0a20bf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0796ff60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0a30bd80>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afd24bf10>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afd24bbf0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1565
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b017db6a0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0796fd30>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1569
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afadead90>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1573
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0aff6afdd0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80157d80>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afd0aff60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1544
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afd24bfb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1692
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b0a06c040>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b261cbf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b07a6f240>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0af6389260>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afaeeed90>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1542
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0afaeef470>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b114cfba0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1571
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0af6388450>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1691
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0af6613f60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0aed613ce0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1563
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b261cbf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0af650fc40>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1542
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ae4eb3f60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b261cbf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0aff7affb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80157fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1562
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0aed7b3bf0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1543
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b310abab0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ae511e610>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0af650fc40>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ae534c5e0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1570
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0adbdeffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1544
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ae524ffb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1690
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0b80157fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1564
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0af6613fb0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1572
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0adbdefd30>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1568
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ad96ee520>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1573
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ad96eeb60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1693
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ad9a8bf10>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1545
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0adbdef150>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1565
# ----------
# <pyarrow._parquet.FileMetaData object at 0x7f0ad4d2bf60>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 470532
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 1569
# ----------

# %% [markdown]
# #### Información estatica de los piezometros

# %%
diccionario_info_piezometros = {
    "06Z01": {
        "locality": "Calle de Murillo, Los Belones, Cartagena",
        "postalCode": "30385",
        "location": [37.630082, -0.777017],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z01E10",
    },
    "06Z02": {
        "locality": "F-34, Cartagena",
        "postalCode": "30383",
        "location": [37.642663, -0.777275],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z02E10",
    },
    "06Z03": {
        "locality": "Camino Rural XVIII, El Algar, Cartagena",
        "postalCode": "30366",
        "location": [37.654261, -0.848734],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z03E10",
    },
    "06Z05": {
        "locality": "N-332, Cartagena",
        "postalCode": "30368",
        "location": [37.6841, -0.8692],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10",
    },
    "06Z06": {
        "locality": "N-332, Cartagena",
        "postalCode": "30368",
        "location": [ 37.7058, -0.8633],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10",
    },
    "06Z07": {
        "locality": "Camino Rural XIII, El Algar, Cartagena",
        "postalCode": "30395",
        "location": [37.7104, -0.8879],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10",
    },
    "06Z08": {
        "locality": "F-35, Cartagena",
        "postalCode": "30710",
        "location": [37.7511, -0.8828],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z08E10",
    },
    "06Z09": {
        "locality": "Autopista del Mediterraneo, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.7452, -0.8679],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z09E10",
    },
    "06Z10": {
        "locality": "Cartagena",
        "postalCode": "30710",
        "location": [37.7618, -0.8673],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z10E10",
    },
    "06Z11": {
        "locality": "Avenida de Muñoz Zambudio, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.7543, -0.8588],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10",
    },
    "06Z12": {
        "locality": "Calle Bergantin, San Javier, Cartagena",
        "postalCode": "30739",
        "location": [37.7755, -0.8514],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10",
    },
    "06Z13": {
        "locality": "Calle de Poseidon, Los Alcazares, Cartagena",
        "postalCode": "30710",
        "location": [37.7696, -0.8385],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z13E10",
    },
    "06Z14": {
        "locality": "N-332, San Javier, Cartagena",
        "postalCode": "30730",
        "location": [37.7883, -0.8387],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10",
    },
    "06Z15": {
        "locality": "Cartagena",
        "postalCode": "30730",
        "location": [37.7802, -0.8302],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z15E10",
    },
    "06Z16": {
        "locality": "Calle del Embalse de la Toba, San Javier, Cartagena",
        "postalCode": "30730",
        "location": [37.8181, -0.8286],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10",
    },
    "06Z17": {
        "locality": "Avenida de la Romeria de San Blas 2, San Javier, Cartagena",
        "postalCode": "30720",
        "location": [37.8059, -0.8168],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z17E10",
    },
    "06Z18": {
        "locality": "Autopista del Mediterraneo, San Javier, Cartagena",
        "postalCode": "30730",
        "location": [37.8247, -0.8165],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z18E10",
    },
    "06Z19": {
        "locality": "Calle de Navacerrada 33, San Javier, Cartagena",
        "postalCode": "30720",
        "location": [37.8178, -0.8085],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z19E10",
    },
    "06Z20": {
        "locality": "Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena",
        "postalCode": "30740",
        "location": [37.8350, -0.8023],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10",
    },
}

# %% [markdown]
# #### Subimos la red piezometrica

# %% [markdown]
# Esta Red incorporará los sondeos que se agrupan alrededor del mar menor

# %%
id_piezometric_net = "urn:ngsi-ld:PiezometricNet:000"

crear_piezometric_net(
    id = str(0).zfill(3), 
    description = "Piezometric Network of the Mar Menor, composed of several boreholes in the coastal area.", 
    name = "Piezometric Network of the Mar Menor",
)
# Out:
# PiezometricNet
# 201

# %% [markdown]
# #### Creamos los piezometros y dispositivos en el OCB

# %%
import math
import time

def check_exists(place_to_search, value_to_search, array=False):
    if array:
        return place_to_search[value_to_search][0] if value_to_search in place_to_search else None

    return place_to_search[value_to_search] if value_to_search in place_to_search else None



# Diccionario que asocia el nombre de la carpeta a la propiedad (CREO QUE NO SE USA)
maper_property_filename = { "Temperatura": "E01-Temperaturafrom_parquet.csv", "Conductividad": "E03-Conductividadfrom_parquet.csv", "Piezometrico":"E10-Piezometricofrom_parquet.csv", "Salinidad":"E11-Salinidadfrom_parquet.csv",
        "Total solido disuelto (TDS)": "E12-Total solido disuelto (TDS)from_parquet.csv",}

# Diccionarios comentados en el apartado de Boyas
maper_property_sensor = { "Temperatura": "TemperatureSensor", "Conductividad": "ConductivitySensor", "Piezometrico":"PiezometricLevelSensor", "Salinidad":"SalinitySensor",
       "Total solido disuelto (TDS)": "TdsSensor", "Solidez":"HardnesSensor"
}

maper_property_controlled = { "Temperatura": "temperature", "Conductividad": "conductivity", "Piezometrico":"piezometricLevel", "Salinidad":"salinity",
       "Total solido disuelto (TDS)": "tds"
}

maper_property_unitcode = { "Temperatura": "CEL", "Conductividad": "microseconds/cm", "Piezometrico":"msnm", "Salinidad":"PSU",
       "Total solido disuelto (TDS)": "mg/l"
}

link_piezometro_sensores = {}
num_piezometros = 0
piezometro_entity = {}

# Recorremos los distintos piezometros
for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = valorCarpeta.columns
    # Creamos IDs para las entidades y dispositivos
    id_entity = f"urn:ngsi-ld:SoundingPlace:{str(num_piezometros).zfill(3)}"
    number_entity = str(num_piezometros).zfill(3)
    number_device = str(num_devices).zfill(3)
    id_piezometro = carpeta.split("-")[0]

    piezometro_entity[carpeta] = id_entity
    controlled_properties = [maper_property_controlled[valor] for valor in sensores if valor != "Date"]

    crear_device(
        id=number_device,
        alternateName = "Multiple sensors for Sounding Place "+ id_piezometro,
        controlled_entity = id_entity,
        controlled_properties = controlled_properties,
        description = "Device from Piezometric Net, belonging to the Sounding Place "+ id_piezometro,
        postalCode = diccionario_info_piezometros[id_piezometro]["postalCode"],
        locality = diccionario_info_piezometros[id_piezometro]["locality"],
        location = diccionario_info_piezometros[id_piezometro]["location"],
        name = "Device " + number_device+" found in Sounding Place "+ id_piezometro,
        source = diccionario_info_piezometros[id_piezometro]["source"],
        dateLastValueReported=valorCarpeta["Date"].iloc[len(valorCarpeta)-1]
    )

    # Para cada fila del csv
    for index, row in valorCarpeta.iterrows():
        if index == 0:
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue

                # Creamos Id para el dispositivo de medicion y el dispositivo de medicion    
                id_device_measurement = f"urn:ngsi-ld:DeviceMeasurement:{str(counter_device_measurements).zfill(3)}"
                
                crear_device_measurement(
                    id=str(counter_device_measurements).zfill(3),
                    deviceType=maper_property_sensor[sensores[contador]],
                    value=row[valorSensor],
                    controlledProperty=maper_property_controlled[valorSensor],
                    observedAt=row["Date"],
                    depth=None,
                    target=None,
                    refDevice=number_device,
                    unitCode=maper_property_unitcode[valorSensor],
                    name="DeviceMeasurement "+ str(counter_device_measurements).zfill(3),
                    source=diccionario_info_piezometros[id_piezometro]["source"],
                    dateLastValueReported=row["Date"]
                )

                counter_device_measurements = counter_device_measurements + 1

                # Asociamos el id del dispositivo de medicion con el id de la entidad y el nombre de la propiedad controlada
                if id_entity not in link_piezometro_sensores:
                    link_piezometro_sensores[id_entity] = {}
                link_piezometro_sensores[id_entity][valorSensor] = id_device_measurement

            entities_id[id_entity] = diccionario_info_piezometros[id_piezometro]["location"]
            # Creamos el sondeo
            crear_sounding(
                id=number_entity,
                locality=diccionario_info_piezometros[id_piezometro]["locality"],
                postalCode=diccionario_info_piezometros[id_piezometro]["postalCode"],
                location=diccionario_info_piezometros[id_piezometro]["location"],
                description="Sounding Place "+ id_piezometro +" which belong to the Piezometric Network in Mar Menor",
                source=diccionario_info_piezometros[id_piezometro]["source"],
                dateLastValueReported=row["Date"],
                numberInNetwork=id_piezometro.split("Z")[1],
                name="Sounding Place "+id_piezometro,
                isPartOf= id_piezometric_net
            )
            num_piezometros += 1

        # Si el indice es 1 entonces haremos la modificación de las entidades
        elif index == 1:
            # Para cada columna del csv
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
                # Recuperamos id del device y modificamos la entidad
                id_device_measurement = link_piezometro_sensores[id_entity][valorSensor]

                modify_entity(
                    value=row[valorSensor],
                    observedAt=row["Date"],
                    unitcode=maper_property_unitcode[valorSensor],
                    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_device_measurement+"/attrs",
                )
                time.sleep(0.2)
        else:
            break
    num_devices = num_devices+1
with open('./variables_entidades/piezometro_entity.pkl', 'wb') as f:
    pickle.dump(piezometro_entity, f)
with open('./variables_entidades/link_piezometro_sensores.pkl', 'wb') as f:
    pickle.dump(link_piezometro_sensores, f)
# Out:
# 06Z06-Sondeo06
# Device
# {'id': 'urn:ngsi-ld:Device:012', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z06'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:000']}, 'controlledProperty': {'type': 'Property', 'value': ['tds', 'conductivity', 'piezometricLevel', 'salinity', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z06'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7058, -0.8633]}}, 'name': {'type': 'Property', 'value': 'Device 012 found in Sounding Place 06Z06'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1200', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:012'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1200'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1201', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:012'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1201'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1202', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:012'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1202'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1203', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:012'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1203'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1204', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:012'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1204'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:000', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:000'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7058, -0.8633]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z06 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z06E10'}, 'numberInNetwork': {'type': 'Property', 'value': '06'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z06'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# 06Z16-Sondeo16
# Device
# {'id': 'urn:ngsi-ld:Device:013', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z16'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:001']}, 'controlledProperty': {'type': 'Property', 'value': ['piezometricLevel', 'conductivity', 'tds', 'salinity', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z16'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle del Embalse de la Toba, San Javier, Cartagena', 'postalCode': '30730'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8181, -0.8286]}}, 'name': {'type': 'Property', 'value': 'Device 013 found in Sounding Place 06Z16'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1205', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:013'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1205'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1206', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:013'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1206'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1207', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:013'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1207'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1208', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:013'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1208'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1209', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:013'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1209'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:001', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:001'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle del Embalse de la Toba, San Javier, Cartagena', 'postalCode': '30730'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8181, -0.8286]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z16 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z16E10'}, 'numberInNetwork': {'type': 'Property', 'value': '16'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z16'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2023-09-01T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2023-09-01T00:05:00Z'}}
# 204
# 06Z12-Sondeo12
# Device
# {'id': 'urn:ngsi-ld:Device:014', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z12'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:002']}, 'controlledProperty': {'type': 'Property', 'value': ['tds', 'piezometricLevel', 'temperature', 'conductivity', 'salinity']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z12'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Bergantin, San Javier, Cartagena', 'postalCode': '30739'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7755, -0.8514]}}, 'name': {'type': 'Property', 'value': 'Device 014 found in Sounding Place 06Z12'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1210', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 2590.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:014'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1210'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1211', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 14.12, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:014'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1211'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1212', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 21.11, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:014'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1212'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1213', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 4050.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:014'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1213'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1214', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 2.34, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:014'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1214'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:002', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:002'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Bergantin, San Javier, Cartagena', 'postalCode': '30739'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7755, -0.8514]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z12 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z12E10'}, 'numberInNetwork': {'type': 'Property', 'value': '12'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z12'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': 2590.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 14.12, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.11, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4050.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.34, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# 06Z11-Sondeo11
# Device
# {'id': 'urn:ngsi-ld:Device:015', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z11'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:003']}, 'controlledProperty': {'type': 'Property', 'value': ['tds', 'conductivity', 'piezometricLevel', 'salinity', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z11'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Avenida de Muñoz Zambudio, Los Alcazares, Cartagena', 'postalCode': '30710'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7543, -0.8588]}}, 'name': {'type': 'Property', 'value': 'Device 015 found in Sounding Place 06Z11'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1215', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 5310.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:015'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1215'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1216', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 8300.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:015'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1216'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1217', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 9.686, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:015'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1217'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1218', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 5.1, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:015'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1218'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1219', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 20.62, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:015'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1219'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:003', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:003'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Avenida de Muñoz Zambudio, Los Alcazares, Cartagena', 'postalCode': '30710'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7543, -0.8588]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z11 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z11E10'}, 'numberInNetwork': {'type': 'Property', 'value': '11'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z11'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': 5310.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8300.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 9.686, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.1, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.61, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# 06Z05-Sondeo05
# Device
# {'id': 'urn:ngsi-ld:Device:016', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z05'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:004']}, 'controlledProperty': {'type': 'Property', 'value': ['salinity', 'conductivity', 'piezometricLevel', 'temperature', 'tds']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z05'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'name': {'type': 'Property', 'value': 'Device 016 found in Sounding Place 06Z05'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1220', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 3.69, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:016'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1220'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1221', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 6240.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:016'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1221'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1222', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 8.541, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:016'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1222'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1223', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 21.44, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:016'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1223'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1224', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 3990.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:016'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1224'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:004', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:004'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.6841, -0.8692]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z05 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z05E10'}, 'numberInNetwork': {'type': 'Property', 'value': '05'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z05'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.69, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 6240.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.541, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.45, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3990.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# 06Z07-Sondeo07
# Device
# {'id': 'urn:ngsi-ld:Device:017', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z07'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:005']}, 'controlledProperty': {'type': 'Property', 'value': ['conductivity', 'tds', 'piezometricLevel', 'salinity', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z07'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XIII, El Algar, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7104, -0.8879]}}, 'name': {'type': 'Property', 'value': 'Device 017 found in Sounding Place 06Z07'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1225', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 8460.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:017'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1225'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1226', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 5410.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:017'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1226'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1227', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 9.495, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:017'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1227'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1228', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 5.22, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:017'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1228'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1229', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 20.5, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:017'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1229'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:005', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:005'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Camino Rural XIII, El Algar, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7104, -0.8879]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z07 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z07E10'}, 'numberInNetwork': {'type': 'Property', 'value': '07'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z07'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': 8460.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5410.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 9.505, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.22, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.5, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# 06Z08-Sondeo08
# Device
# {'id': 'urn:ngsi-ld:Device:018', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z08'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:006']}, 'controlledProperty': {'type': 'Property', 'value': ['salinity', 'tds', 'conductivity', 'piezometricLevel', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z08'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'F-35, Cartagena', 'postalCode': '30710'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z08E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7511, -0.8828]}}, 'name': {'type': 'Property', 'value': 'Device 018 found in Sounding Place 06Z08'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1230', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 4.3, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:018'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z08E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1230'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1231', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 4480.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:018'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z08E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1231'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# ...
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.541, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2140.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.14, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3350.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# 06Z14-Sondeo14
# Device
# {'id': 'urn:ngsi-ld:Device:029', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z14'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:017']}, 'controlledProperty': {'type': 'Property', 'value': ['salinity', 'tds', 'temperature', 'conductivity', 'piezometricLevel']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z14'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, San Javier, Cartagena', 'postalCode': '30730'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7883, -0.8387]}}, 'name': {'type': 'Property', 'value': 'Device 029 found in Sounding Place 06Z14'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1284', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:029'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1284'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1285', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 2060.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:029'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1285'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1286', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 20.48, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:029'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1286'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1287', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 3220.0, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:029'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1287'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1288', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 13.051, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:029'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1288'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:017', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:017'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'N-332, San Javier, Cartagena', 'postalCode': '30730'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7883, -0.8387]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z14 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z14E10'}, 'numberInNetwork': {'type': 'Property', 'value': '14'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z14'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2060.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.49, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3220.0, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 13.051, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# 06Z20-Sondeo20
# Device
# {'id': 'urn:ngsi-ld:Device:030', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Sounding Place 06Z20'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:SoundingPlace:018']}, 'controlledProperty': {'type': 'Property', 'value': ['conductivity', 'tds', 'salinity', 'temperature', 'piezometricLevel']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device from Piezometric Net, belonging to the Sounding Place 06Z20'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'name': {'type': 'Property', 'value': 'Device 030 found in Sounding Place 06Z20'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1289', 'deviceType': {'type': 'Property', 'value': 'ConductivitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'conductivity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:030'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1289'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'microseconds/cm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1290', 'deviceType': {'type': 'Property', 'value': 'TdsSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'tds'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:030'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1290'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mg/l'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1291', 'deviceType': {'type': 'Property', 'value': 'SalinitySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'salinity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:030'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1291'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'PSU'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1292', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:030'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1292'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1293', 'deviceType': {'type': 'Property', 'value': 'PiezometricLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'piezometricLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:030'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1293'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'msnm'}}
# 201
# {'id': 'urn:ngsi-ld:SoundingPlace:018', 'identifier': {'type': 'Property', 'value': 'SoundingPlace:018'}, 'type': 'SoundingPlace', 'category': {'type': 'Property', 'value': 'sensor'}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Calle Francesco Borromini 3, San Pedro del Pinatar, Cartagena', 'postalCode': '30740'}, 'verified': {'type': 'Property', 'value': True}}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.835, -0.8023]}}, 'description': {'type': 'Property', 'value': 'Sounding Place 06Z20 which belong to the Piezometric Network in Mar Menor'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06Z20E10'}, 'numberInNetwork': {'type': 'Property', 'value': '20'}, 'name': {'type': 'Property', 'value': 'Sounding Place 06Z20'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'isPartOf': {'type': 'Relationship', 'object': 'urn:ngsi-ld:PiezometricNet:000'}}
# <Response [201]>
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2019-12-13T00:05:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2019-12-13T00:05:00Z'}}
# 204

# %% [markdown]
# #### Conexion con TimeScale y insertamos los datos como con las Boyas

# %%
import psycopg2
from datetime import datetime
import uuid
# Conectarse a la base de datos
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="orion",
    user="orion",
    password="orion"
)

cursor = conn.cursor()
datos_a_insertar = []

for carpeta, valorCarpeta in dfs.items():
    id_entity = piezometro_entity[carpeta]
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    for index, row in valorCarpeta.iterrows():
        if index == len(valorCarpeta)-1 or index == 0 or index == 1:
            continue
        for contador,valorSensor in enumerate(sensores):
            if valorSensor == "Date":
                continue


            id_device_measurement = link_piezometro_sensores[id_entity][valorSensor]

            fecha_hora = datetime.strptime(row["Date"], "%Y-%m-%dT%H:%M:%SZ")

            value = row[valorSensor]
            if math.isnan(row[valorSensor]):
                    value = -99

            datos_a_insertar.append(
                (f'urn:ngsi-ld:attributes2:{uuid.uuid4()}', 'https://smartdatamodels.org/dataModel.DeviceMeasurement/numValue', 'Replace', id_device_measurement, fecha_hora, True, maper_property_unitcode[valorSensor], 'None', 'Number', None, None, value, None, None, None, None, None, None, None, None, datetime.now())
            )
            
            if len(datos_a_insertar) > 100000:
                consulta_insercion = f"INSERT INTO attributes VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
                print(f"Insertando {len(datos_a_insertar)} filas en la tabla attributes")
                try:
                    # Ejecutar la consulta para insertar los datos
                    cursor.executemany(consulta_insercion, datos_a_insertar)
                    conn.commit()
                    datos_a_insertar = []
                    print(f"Se han insertado {cursor.rowcount} filas en la tabla attributes")
                except (Exception, psycopg2.DatabaseError) as error:
                    conn.rollback()
                # Confirmar la transacción
                    print(f"Error: {error}")

if len(datos_a_insertar) > 0:
    consulta_insercion = f"INSERT INTO attributes VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    print(f"Insertando {len(datos_a_insertar)} filas en la tabla attributes")
    try:
        # Ejecutar la consulta para insertar los datos
        cursor.executemany(consulta_insercion, datos_a_insertar)
        conn.commit()
        datos_a_insertar = []
        print(f"Se han insertado {cursor.rowcount} filas en la tabla attributes")
    except (Exception, psycopg2.DatabaseError) as error:
        conn.rollback()
    # Confirmar la transacción
        print(f"Error: {error}")

# Cerrar el cursor y la conexión
cursor.close()
conn.close()
# Out:
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 28843 filas en la tabla attributes
# Se han insertado 28843 filas en la tabla attributes

# %% [markdown]
# #### Modificación de las entidades de ORION para que tengan los ultimos valores

# %%
for carpeta, valorCarpeta in dfs.items():
    ultimos_valores = valorCarpeta.iloc[len(valorCarpeta)-1]
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    id_entity = piezometro_entity[carpeta]
    for contador,valorSensor in enumerate(sensores):
        if valorSensor == "Date":
            continue
        
        id_device_measurement = link_piezometro_sensores[id_entity][valorSensor]

        modify_entity(
            value=ultimos_valores[valorSensor],
            observedAt=ultimos_valores["Date"],
            unitcode=maper_property_unitcode[valorSensor],
            url="http://localhost:1026/ngsi-ld/v1/entities/"+id_device_measurement+"/attrs",
        )
# Out:
# 06Z06-Sondeo06
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 9640.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06Z16-Sondeo16
# modify_content
# {'numValue': {'type': 'Property', 'value': 7180.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 17.341, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.98, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4590.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z12-Sondeo12
# modify_content
# {'numValue': {'type': 'Property', 'value': 4430.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 13.17, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.58, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.18, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2840.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z11-Sondeo11
# modify_content
# {'numValue': {'type': 'Property', 'value': 4330.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.196, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.68, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.55, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2770.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z05-Sondeo05
# modify_content
# {'numValue': {'type': 'Property', 'value': 4720.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.331, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.74, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.48, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3020.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z07-Sondeo07
# modify_content
# {'numValue': {'type': 'Property', 'value': 7230.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.865, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 19.96, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.47, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4630.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z08-Sondeo08
# modify_content
# {'numValue': {'type': 'Property', 'value': 11020.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 15.941, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.05, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7.01, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 7050.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z03-Sondeo03
# modify_content
# {'numValue': {'type': 'Property', 'value': 1890.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 16.699, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.78, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 1210.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z13-Sondeo13
# modify_content
# {'numValue': {'type': 'Property', 'value': 7440.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 6.69, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4.54, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.56, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4760.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z02-Sondeo02
# modify_content
# {'numValue': {'type': 'Property', 'value': 1500.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.539, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.32, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 960.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z09-Sondeo09
# modify_content
# {'numValue': {'type': 'Property', 'value': 8540.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 8.694, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5.33, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 5470.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z15-Sondeo15
# modify_content
# {'numValue': {'type': 'Property', 'value': 4520.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 6.746, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.64, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2890.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z19-Sondeo19
# modify_content
# {'numValue': {'type': 'Property', 'value': 6240.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 9.457, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.96, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.73, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3990.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z10-Sondeo10
# modify_content
# {'numValue': {'type': 'Property', 'value': 6310.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 14.073, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.39, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.74, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4040.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z17-Sondeo17
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 9.081, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.32, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z18-Sondeo18
# modify_content
# {'numValue': {'type': 'Property', 'value': 4930.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 16.57, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.71, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.85, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3160.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z01-Sondeo01
# modify_content
# {'numValue': {'type': 'Property', 'value': 3840.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 1.591, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.22, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.16, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2460.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z14-Sondeo14
# modify_content
# {'numValue': {'type': 'Property', 'value': 5780.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 12.711, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.83, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3.37, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 3700.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# 06Z20-Sondeo20
# modify_content
# {'numValue': {'type': 'Property', 'value': 4050.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 10.801, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'msnm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.71, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.32, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'PSU'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2590.0, 'observedAt': '2024-06-02T23:55:00Z', 'unitCode': 'mg/l'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-02T23:55:00Z'}}
# 204

# %% [markdown]
# #### Consulta para ver los esquemas

# %%
''' Da un error que causa el crash del kernel
import psycopg2
import datetime
# Conectarse a la base de datos
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="orion",
    user="orion",
    password="orion"
)
cursor = conn.cursor()

cursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema='public'")

# Iterar sobre las tablas
for tabla in cursor.fetchall():

    nombre_tabla = tabla[0]
    if nombre_tabla == "attributes":
        print(f"Esquema de la tabla '{nombre_tabla}':")
        
        # Obtener información sobre las columnas de la tabla
        cursor.execute(f"SELECT column_name, data_type FROM information_schema.columns WHERE table_name = '{nombre_tabla}'")
        
        # Mostrar el esquema de la tabla
        for columna in cursor.fetchall():
            print(columna)

        cursor.execute(f"SELECT * FROM {nombre_tabla}")
        contador = 0
        # Mostrar el esquema de la tabla
        for columna in cursor.fetchall():
            contador += 1
            print(columna)
            if contador > 50000:
                break
        #('urn:ngsi-ld:attribute:instance:df60ec4c-d714-11ee-aec1-0242ac120105', 'https://smartdatamodels.org/depth', 'urn:ngsi-ld:DeviceMeasurement:006', 'urn:ngsi-ld:attribute:instance:df60ec2e-d714-11ee-aec1-0242ac120105', 'None', None, None, 'String', '-1.6', None, None, None, None, None, None, None, None, None, None, datetime(2024, 2, 29, 15, 11, 54, 204000))


# Cerrar el cursor y la conexión
cursor.close()
conn.close()
'''
# Out:
# ' Da un error que causa el crash del kernel\nimport psycopg2\nimport datetime\n# Conectarse a la base de datos\nconn = psycopg2.connect(\n    host="localhost",\n    port="5432",\n    database="orion",\n    user="orion",\n    password="orion"\n)\ncursor = conn.cursor()\n\ncursor.execute("SELECT table_name FROM information_schema.tables WHERE table_schema=\'public\'")\n\n# Iterar sobre las tablas\nfor tabla in cursor.fetchall():\n\n    nombre_tabla = tabla[0]\n    if nombre_tabla == "attributes":\n        print(f"Esquema de la tabla \'{nombre_tabla}\':")\n        \n        # Obtener información sobre las columnas de la tabla\n        cursor.execute(f"SELECT column_name, data_type FROM information_schema.columns WHERE table_name = \'{nombre_tabla}\'")\n        \n        # Mostrar el esquema de la tabla\n        for columna in cursor.fetchall():\n            print(columna)\n\n        cursor.execute(f"SELECT * FROM {nombre_tabla}")\n        contador = 0\n        # Mostrar el esquema de la tabla\n        for columna in cursor.fetchall():\n            contador += 1\n            print(columna)\n            if contador > 50000:\n                break\n        #(\'urn:ngsi-ld:attribute:instance:df60ec4c-d714-11ee-aec1-0242ac120105\', \'https://smartdatamodels.org/depth\', \'urn:ngsi-ld:DeviceMeasurement:006\', \'urn:ngsi-ld:attribute:instance:df60ec2e-d714-11ee-aec1-0242ac120105\', \'None\', None, None, \'String\', \'-1.6\', None, None, None, None, None, None, None, None, None, None, datetime(2024, 2, 29, 15, 11, 54, 204000))\n\n\n# Cerrar el cursor y la conexión\ncursor.close()\nconn.close()\n'

# %% [markdown]
# ### Subiendo la información de las Ramblas

# %% [markdown]
# #### Información estatica de las ramblas

# %%
# Se han establecido manualmente los ids, aunque no haría falta, se podría hacer como en las otras
maper_rambla_id = {
    "06A01": "urn:ngsi-ld:Ravine:001",
    "06A02": "urn:ngsi-ld:Ravine:002",
    "06A03": "urn:ngsi-ld:Ravine:003",
    "06A04": "urn:ngsi-ld:Ravine:004",
    "06A05": "urn:ngsi-ld:Ravine:005",
    "06A06": "urn:ngsi-ld:Ravine:006",
    "06A18": "urn:ngsi-ld:Ravine:007",
    "06A19": "urn:ngsi-ld:Ravine:008",
    "06P02": "urn:ngsi-ld:Ravine:009",
    "06P04": "urn:ngsi-ld:Ravine:010",
    "06P05": "urn:ngsi-ld:Ravine:011",
    "01M02": "urn:ngsi-ld:Ravine:012",
    "06B01": "urn:ngsi-ld:Ravine:013"
}

diccionario_info_ramblas = {
    "06A01": {
        "description": "Control frame 06A01 in La Puebla, Rambla del Albujon.",
        "locality": "RM-F35, La Puebla, Cartagena",
        "postalCode": "30395",
        "location": [37.7207, -0.9144],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12",
        "section": 5,
        "nextSection": [maper_rambla_id["06A18"]],
        "previousSection": [maper_rambla_id["06A02"]],
    },
    "06A02": {
        "description": "Control frame 06A02 in Pozo Estrecho, Albujón watercourse.",
        "locality": "Pozo Estrecho, Cartagena",
        "postalCode": "30594",
        "location": [37.7239, -0.9793],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12",
        "section": 4,
        "nextSection": [maper_rambla_id["06A01"]],
        "previousSection": [maper_rambla_id["06A03"]],
    },
    "06A03": {
        "description": "Control frame 06A03 Rambla del Albujón",
        "locality": "Rambla de El Albujón, Cartagena",
        "postalCode": "30330",
        "location": [37.7213, -1.0491],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12",
        "section": 3,
        "nextSection": [maper_rambla_id["06A02"]],
        "previousSection": [maper_rambla_id["06A04"]],
    },
    "06A04": {
        "description": "Control frame 06A04 in el Estrecho, rambla del Albujón",
        "locality": "Estrecho de Fuente Álamo, Cartagena",
        "postalCode": "30332",
        "location": [37.7259, -1.1098],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12",
        "section": 2,
        "nextSection": [maper_rambla_id["06A03"]],
        "previousSection": [maper_rambla_id["06A05"],maper_rambla_id["06A06"]],
    },
    "06A05": {
        "description": "Control frame 06A05 in Fuente Álamo, rambla del Albujón",
        "locality": "Fuente Álamo, Murcia",
        "postalCode": "30320",
        "location": [37.7247, -1.1721],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12",
        "section": 1,
        "nextSection": [maper_rambla_id["06A04"]],
        "previousSection": None,
    },
    "06A06": {
        "description": "Control frame 06A06 in Los Cegarras, rambla de la Murta",
        "locality": "Cabecico del Rey, Murcia",
        "postalCode": "30154",
        "location": [37.7541, -1.1443],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12",
        "section": 1,
        "nextSection": [maper_rambla_id["06A04"]],
        "previousSection": None,
    },
    "06A18": {
        "description": "Mouth 06A05 Rambla del Albujón",
        "locality": "Bahía Bella, Cartagena",
        "postalCode": "30368",
        "location": [37.7163, -0.8610],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12",
        "section": 6,
        "nextSection": None,
        "previousSection": [maper_rambla_id["06A01"]],
    },
    "06A19": {
        "description": "Control frame in Rambla de la Maraña- Balsicas",
        "locality": "Los Camachos, Cartagena",
        "postalCode": "30592",
        "location": [37.7953, -0.9415],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06P02": {
        "description": "Control frame 06P02 in Rambla de la Maraña- Balsicas",
        "locality": "Torre Pacheco, Murcia",
        "postalCode": "30708",
        "location": [37.7492, -0.9921],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06P04": {
        "description": "Control frame 06P04 in Torre Pacheco",
        "locality": "La Murta-Carrascoy, Murcia",
        "postalCode": "30153",
        "location": [37.8270, -1.2107],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06P05": {
        "description": "Control frame 06P04 in San Javier (El Mirador)",
        "locality": "El Mirador, San Javier, Murcia",
        "postalCode": "30592",
        "location": [37.8359, -0.8757],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "01M02": {
        "description": "Meteorological-Hydrological Station 01M02 el Relojero (AMETSE)",
        "locality": "El Relojero, La Alberca, Murcia",
        "postalCode": "30155",
        "location": [37.9136, -1.1190],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    },
    "06B01": {
        "description": "Elevation 06B01 el Albujón",
        "locality": "Bahía bellas, Los Alcazares, Cartagena",
        "postalCode": "30368",
        "location": [37.7175, -0.8598],
        "unitCode": "MTR",
        "source": "https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06B01L03",
        "section": 1,
        "nextSection": None,
        "previousSection": None,
    }
}

# %% [markdown]
# #### Creación de la Red Acuatica que representa la rmbla del Albujon

# %%
import requests
id_water_network = "urn:ngsi-ld:WaterNetwork:000"

crear_water_network(
    id = str(0).zfill(3), 
    isComposedOf = [], 
    description = "Una de las ramblas mas importantes de la Región compuesta a su vez por un conjunto de otras ramblas", 
    name = "Rambla del Albujón", 
)
# Out:
# WaterNetwork
# 201

# %% [markdown]
# #### Lectura de los csv/parquet para juntar los datos

# %%
import os
import pandas as pd
import glob
import pyarrow.parquet as pq
import numpy as np
# Especifica la ruta de la carpeta principal
carpeta = "/home/thinking/raw/SAIHdatasActualizados/Ramblas/"

# Utiliza os.listdir() para obtener una lista de elementos en la carpeta
elementos_en_carpeta = os.listdir(carpeta)

# Filtra solo las carpetas en la lista de elementos
carpetas = [elemento for elemento in elementos_en_carpeta if os.path.isdir(os.path.join(carpeta, elemento))]

# DataFrame vacío para almacenar los datos
dfs = {}


# Imprime la lista de carpetas
for carpeta_actual in carpetas:
    df_total = pd.DataFrame()
    archivos_parquet = glob.glob(os.path.join(carpeta+carpeta_actual, "*.parquet"))
    for archivo in archivos_parquet:

        df_temporal = pd.read_parquet(archivo)
        tabla = pq.ParquetFile(archivo)

        #df_temporal.to_csv(archivo.split(".")[0]+"from_parquet.csv", index=False)
        
        if(len(df_total) == 0):
            df_total = df_temporal
        else:
            #Hacer un merge de df_total y df_temporal por la columna "Date"
            df_total = pd.merge(df_total, df_temporal, on="Date", how="outer")
    dfs[carpeta_actual] = df_total

for key, df in dfs.items():
    # Convierte la columna "Date" a tipo datetime
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")

for key, df in dfs.items():
    numeric_cols = df.columns.copy()
    numeric_cols = numeric_cols.drop("Date")
    df.replace('-', float('nan'), inplace=True)
    df.replace("null", float('nan'), inplace=True)
    df[numeric_cols] = df[numeric_cols].astype(float)
    df["Date"] = pd.to_datetime(df["Date"])
    # Formatea la columna "Date" en el nuevo formato
    df["Date"] = df["Date"].dt.strftime("%Y-%m-%dT%H:%M:%SZ")

# %% [markdown]
# #### Codigo para crear las ramblas y los dispositivos

# %%
import math
import time

#num_devices = 31
#counter_device_measurements = 1300

# Mismos Diccionarios que en el apartado de Boyas
maper_property_sensor = { "Volumen":"VolumeSensor","Presion":"PressureSensor","Temperatura": "TemperatureSensor", "Presion Atmosferica":"AtmosphericPressureSensor","Direccion del Viento":"WindDirectionSensor","Velocidad del Viento":"WindSpeedSensor" ,"Nivel": "WaterLevelSensor", "Pluviometro":"PrecipitationSensor","Caudal":"WaterFlowSensor", "Humedad":"HumiditySensor","Conductividad":"ConductivitySensor",
}

maper_property_controlled = { "Volumen":"volume","Presion":"pressure","Presion Atmosferica":"atmosphericPressure","Direccion del Viento":"windDirection","Velocidad del Viento":"windSpeed","Temperatura": "temperature", "Nivel": "waterLevel", "Pluviometro":"precipitation","Caudal":"waterFlow", "Humedad":"humidity","Conductividad":"conductivity"
}

maper_property_unitcode = { "Volumen":"m3","Presion":"bar", "Presion Atmosferica":"mbar", "Direccion del Viento":"°","Velocidad del Viento":"m/s","Temperatura": "CEL", "Conductividad": "microseconds/cm", "Nivel": "m", "Pluviometro":"mm","Caudal":"m3/s", "Humedad":"%"
}


# Diccionario que asocia el nombre de la carpeta a la propiedad (CREO Q NO SE USA)
maper_property_filename = {
    "Volumen Deposito":"B01-Volumen Depositofrom_parquet.csv","Presion Tuberia Salida Impulsion":"D03-Presion Tuberia Salida Impulsionfrom_parquet.csv","Presion Atmosferica":"D03-Presion Atmosfericafrom_parquet.csv",
    "Direccion del Viento":"D04-Direccion del Vientofrom_parquet.csv","Velocidad del Viento":"D09-Velocidad del Vientofrom_parquet.csv","Temperatura": "D05-Temperaturafrom_parquet.csv", 
    "Nivel": "U12-Nivelfrom_parquet.csv", "Pluviometro":"P01-Pluviometrofrom_parquet.csv","Caudal":"Q01-Caudalfrom_parquet.csv", "Humedad":"D06-Humedadfrom_parquet.csv",
    "Conductividad Aspiracion":"E03-Conductividad Aspiracionfrom_parquet.csv", "Nivel sobre Vertedero":"L01-Nivel sobre Vertederofrom_parquet.csv",
    "Nivel Deposito":"L02-Nivel Depositofrom_parquet.csv","Nivel Captacion": "L03-Nivel Captacionfrom_parquet.csv", "Caudal Salida al Mar": "Q01-Caudal Salida al Marfrom_parquet.csv",
    "Caudal Salida a RmblAlbujon":"Q02-Caudal Salida a RmblAlbujonfrom_parquet.csv", "Caudal Salida ElvAlbujon a ElvNarejos":"Q03-Caudal Salida ElvAlbujon a ElvNarejosfrom_parquet.csv"
}


# Diccionario para asociad device measurement con las entidades
link_rambla_sensores = {}
## Diccionario que asocia rambla con la carpeta
rambla_entity = {}
num_ramblas = 0

# En este diccionario se indican las ramblas que pertenece a la rambla del Albujón
# Se rellenara con el id de la entidad asociada a cada una de las ramblas
ramblas_albujon = {
    "06A06": "",
    "06A05": "",
    "06A04": "",
    "06A03": "",
    "06A02": "",
    "06A18": "",
    "06A01": ""
}

# Para cada rambla
for carpeta, valorCarpeta in dfs.items():
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))

    # Obtenemos id de la rambla
    id_rambla = carpeta.split("-")[0]
    id_entity = maper_rambla_id[id_rambla]

    # Añadimos el id de la rambla a la lista de ramblas de la rambla del Albujón
    if id_rambla in ramblas_albujon:
        ramblas_albujon[id_rambla] = id_entity

    # obtenemos numero entidad y dispositivo
    number_entity = id_entity.split(":")[-1]
    number_device = str(num_devices).zfill(3)

    rambla_entity[carpeta] = id_entity
    
    if (id_rambla not in diccionario_info_ramblas):
        continue

    controlled_properties = []

    # Se añaden las propiedades controladas, hay que tener en cuenta que hay algunas repetidas
    # como Nivel deposito y Nivel capacitación, en ese caso almacenamos solo "Nivel"
    for valor in sensores:
        if valor != "Date":
            if valor in maper_property_controlled:
                controlled_properties.append(maper_property_controlled[valor])
            else:
                controlled_properties.append(valor.split(" ")[0])

    # Creamos el dispositivo
    crear_device(
        id=number_device,
        alternateName = "Multiple sensors for Ravine "+ id_rambla,
        controlled_entity = id_entity,
        controlled_properties = controlled_properties,
        description = "Device placed in Ravine "+ id_rambla+" that flow into Mar Menor",
        postalCode = diccionario_info_ramblas[id_rambla]["postalCode"],
        locality = diccionario_info_ramblas[id_rambla]["locality"],
        location = diccionario_info_ramblas[id_rambla]["location"],
        name = "Device " + number_device+" found in Piezometric Point "+ id_rambla,
        source = diccionario_info_ramblas[id_rambla]["source"],
        dateLastValueReported=valorCarpeta["Date"].iloc[len(valorCarpeta)-1]
    )

    # Para cada fila del csv
    for index, row in valorCarpeta.iterrows():
        # Si es la primera fila creamos las entidades
        if index == 0:
            for contador,valorSensor in enumerate(sensores):
                original = valorSensor
                if valorSensor == "Date":
                    continue

                id_device_measurement = f"urn:ngsi-ld:DeviceMeasurement:{str(counter_device_measurements).zfill(3)}"

                # Si el nombre del sensor tiene más de una palabra y no esta en el diccionario de propiedades
                # la segunda se considera el lugar de la medición
                measurementPlace = None
                if len(valorSensor.split(" "))>0 and valorSensor not in maper_property_controlled:
                    measurementPlace = " ".join(valorSensor.split(" ")[1:])
                    valorSensor = valorSensor.split(" ")[0]
                
                crear_device_measurement(
                    id=str(counter_device_measurements).zfill(3),
                    deviceType=maper_property_sensor[valorSensor],
                    value=row[original],
                    controlledProperty=maper_property_controlled[valorSensor],
                    observedAt=row["Date"],
                    depth=None,
                    target=measurementPlace,
                    refDevice=number_device,
                    unitCode=maper_property_unitcode[valorSensor],
                    name="DeviceMeasurement "+ str(counter_device_measurements).zfill(3),
                    source=diccionario_info_ramblas[id_rambla]["source"],
                    dateLastValueReported=row["Date"]
                )

                counter_device_measurements = counter_device_measurements + 1
                
                # Asociamos el id del dispositivo de medicion con el id de la entidad y el nombre de la propiedad controlada
                if id_entity not in link_rambla_sensores:
                    link_rambla_sensores[id_entity] = {}
                if valorSensor not in link_rambla_sensores[id_entity]:
                    link_rambla_sensores[id_entity][valorSensor] = {}

                link_rambla_sensores[id_entity][valorSensor][measurementPlace] = id_device_measurement
    
            entities_id[id_entity] = diccionario_info_ramblas[id_rambla]["location"]
            
            # Creamos la rambla
            crear_rambla(
                id=number_entity,
                dateLastValueReported=row["Date"],
                description=diccionario_info_ramblas[id_rambla]["description"],
                locality=diccionario_info_ramblas[id_rambla]["locality"],
                postalCode=diccionario_info_ramblas[id_rambla]["postalCode"],
                source=diccionario_info_ramblas[id_rambla]["source"],
                location=diccionario_info_ramblas[id_rambla]["location"],
                section=diccionario_info_ramblas[id_rambla]["section"],
                nextSection=diccionario_info_ramblas[id_rambla]["nextSection"],
                previousSection=diccionario_info_ramblas[id_rambla]["previousSection"],
                name="Ravine " + id_rambla,
                isPartOf=id_water_network if id_rambla in ramblas_albujon else None
            )

            num_ramblas += 1

        # Si el indice es 1 entonces haremos la modificación de las entidades
        elif index == 1:
            counters_valorSensor= {}
            for contador,valorSensor in enumerate(sensores):
                if valorSensor == "Date":
                    continue
                original = valorSensor
                
                # Mismo proceso que el de arriba
                measurementPlace = None
                if len(valorSensor.split(" "))>0 and valorSensor not in maper_property_controlled:
                    measurementPlace = " ".join(valorSensor.split(" ")[1:])
                    valorSensor = valorSensor.split(" ")[0]

                if valorSensor not in counters_valorSensor:
                    counters_valorSensor[valorSensor] = 0

                # Recuperamos el ide del dispositivo de medicion y modificamos la entidad
                id_device_measurement = link_rambla_sensores[id_entity][valorSensor][measurementPlace]
                counters_valorSensor[valorSensor] += 1

                modify_entity(
                    value=row[original],
                    observedAt=row["Date"],
                    unitcode=maper_property_unitcode[valorSensor],
                    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_device_measurement+"/attrs",
                )
                time.sleep(0.2)
        else:
            break
    num_devices = num_devices+1

with open('./variables_entidades/rambla_entity.pkl', 'wb') as f:
    pickle.dump(rambla_entity, f)
with open('./variables_entidades/link_rambla_sensores.pkl', 'wb') as f:
    pickle.dump(link_rambla_sensores, f)
# Out:
# 06A02-Pozo Estrecho
# Device
# {'id': 'urn:ngsi-ld:Device:031', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A02'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:002']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A02 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Pozo Estrecho, Cartagena', 'postalCode': '30594'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7239, -0.9793]}}, 'name': {'type': 'Property', 'value': 'Device 031 found in Piezometric Point 06A02'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1294', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:031'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1294'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1295', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:031'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1295'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1296', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:031'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1296'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1297', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:031'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A02U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1297'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-08T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-08T00:05:00Z'}}
# 204
# 06P04-La Murta
# Device
# {'id': 'urn:ngsi-ld:Device:032', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06P04'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:010']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06P04 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'La Murta-Carrascoy, Murcia', 'postalCode': '30153'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.827, -1.2107]}}, 'name': {'type': 'Property', 'value': 'Device 032 found in Piezometric Point 06P04'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1298', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:032'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1298'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1299', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 14.51, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:032'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P04P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1299'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 14.72, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# 06P02-Torre Pacheco
# Device
# {'id': 'urn:ngsi-ld:Device:033', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06P02'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:009']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06P02 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Torre Pacheco, Murcia', 'postalCode': '30708'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7492, -0.9921]}}, 'name': {'type': 'Property', 'value': 'Device 033 found in Piezometric Point 06P02'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1300', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:033'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1300'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1301', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 12.33, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:033'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1301'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 12.22, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# 06A05-Fuente Alamo
# Device
# {'id': 'urn:ngsi-ld:Device:034', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A05'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:005']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A05 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Fuente Álamo, Murcia', 'postalCode': '30320'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7247, -1.1721]}}, 'name': {'type': 'Property', 'value': 'Device 034 found in Piezometric Point 06A05'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1302', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:034'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1302'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1303', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:034'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1303'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1304', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:034'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1304'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1305', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:034'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A05U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1305'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-05-06T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-05-06T00:05:00Z'}}
# 204
# 06P05-San Javier
# Device
# {'id': 'urn:ngsi-ld:Device:035', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06P05'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:011']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06P05 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Mirador, San Javier, Murcia', 'postalCode': '30592'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.8359, -0.8757]}}, 'name': {'type': 'Property', 'value': 'Device 035 found in Piezometric Point 06P05'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1306', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2017-08-25T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-08-25T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:035'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1306'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1307', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2017-08-25T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2017-08-25T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:035'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06P05P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1307'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2017-08-25T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2017-08-25T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2017-08-25T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2017-08-25T00:05:00Z'}}
# 204
# 06A19-La Marana
# Device
# {'id': 'urn:ngsi-ld:Device:036', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A19'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:008']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A19 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Los Camachos, Cartagena', 'postalCode': '30592'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7953, -0.9415]}}, 'name': {'type': 'Property', 'value': 'Device 036 found in Piezometric Point 06A19'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1308', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:036'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1308'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1309', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:036'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1309'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1310', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:036'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1310'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1311', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:036'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A19U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1311'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-04-09T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-04-09T00:05:00Z'}}
# 204
# 06A04-El Estrecho
# Device
# {'id': 'urn:ngsi-ld:Device:037', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A04'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:004']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A04 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Estrecho de Fuente Álamo, Cartagena', 'postalCode': '30332'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7259, -1.1098]}}, 'name': {'type': 'Property', 'value': 'Device 037 found in Piezometric Point 06A04'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1312', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:037'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1312'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1313', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:037'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1313'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1314', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:037'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1314'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1315', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:037'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A04U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1315'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# 06A01-La Puebla
# Device
# {'id': 'urn:ngsi-ld:Device:038', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A01'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:001']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A01 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'RM-F35, La Puebla, Cartagena', 'postalCode': '30395'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7207, -0.9144]}}, 'name': {'type': 'Property', 'value': 'Device 038 found in Piezometric Point 06A01'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1316', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:038'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1316'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1317', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:038'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1317'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1318', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:038'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1318'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1319', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:038'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A01U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1319'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-15T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-15T00:05:00Z'}}
# 204
# 06A03-Rbla Albujon
# Device
# {'id': 'urn:ngsi-ld:Device:039', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A03'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:003']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A03 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Rambla de El Albujón, Cartagena', 'postalCode': '30330'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7213, -1.0491]}}, 'name': {'type': 'Property', 'value': 'Device 039 found in Piezometric Point 06A03'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1320', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:039'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1320'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1321', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:039'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1321'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1322', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:039'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1322'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1323', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:039'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A03U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1323'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# 01M02-Relojero
# Device
# {'id': 'urn:ngsi-ld:Device:040', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 01M02'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:012']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'atmosphericPressure', 'windSpeed', 'windDirection', 'humidity', 'temperature']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 01M02 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'El Relojero, La Alberca, Murcia', 'postalCode': '30155'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.9136, -1.119]}}, 'name': {'type': 'Property', 'value': 'Device 040 found in Piezometric Point 01M02'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1324', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:040'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1324'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1325', 'deviceType': {'type': 'Property', 'value': 'AtmosphericPressureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'atmosphericPressure'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:040'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1325'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mbar'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1326', 'deviceType': {'type': 'Property', 'value': 'WindSpeedSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'windSpeed'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:040'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1326'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm/s'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1327', 'deviceType': {'type': 'Property', 'value': 'WindDirectionSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'windDirection'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:040'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1327'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': '°'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1328', 'deviceType': {'type': 'Property', 'value': 'HumiditySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'humidity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:040'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1328'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': '%'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1329', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2018-08-21T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2018-08-21T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:040'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=01M02P01'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1329'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# modify_content
# ...
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1337', 'deviceType': {'type': 'Property', 'value': 'VolumeSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'volume'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:041'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06B01L03'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1337'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3'}, 'target': {'type': 'Property', 'value': 'Deposito'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1338', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:041'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06B01L03'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1338'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}, 'target': {'type': 'Property', 'value': 'Salida al Mar'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'bar'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 47.18, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.313, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm3'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2021-06-23T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-06-23T00:05:00Z'}}
# 204
# 06A18-Desemboc Rbla Albujon
# Device
# {'id': 'urn:ngsi-ld:Device:042', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A18'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:007']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'humidity', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A18 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Bahía Bella, Cartagena', 'postalCode': '30368'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7163, -0.861]}}, 'name': {'type': 'Property', 'value': 'Device 042 found in Piezometric Point 06A18'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1339', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-01-12T12:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:042'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1339'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1340', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.06, 'observedAt': '2021-01-12T12:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:042'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1340'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1341', 'deviceType': {'type': 'Property', 'value': 'HumiditySensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'humidity'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-01-12T12:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:042'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1341'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': '%'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1342', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-01-12T12:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:042'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1342'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1343', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:00:00Z'}, 'numValue': {'type': 'Property', 'value': 0.178, 'observedAt': '2021-01-12T12:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:042'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A18U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1343'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-01-12T12:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.06, 'observedAt': '2021-01-12T12:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-01-12T12:05:00Z', 'unitCode': '%'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2021-01-12T12:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.18, 'observedAt': '2021-01-12T12:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2021-01-12T12:05:00Z'}}
# 204
# 06A06-Los Cegarras
# Device
# {'id': 'urn:ngsi-ld:Device:043', 'alternateName': {'type': 'Property', 'value': 'Multiple sensors for Ravine 06A06'}, 'areaServed': {'type': 'Property', 'value': 'Mar Menor'}, 'type': 'Device', 'controlledAsset': {'type': 'Relationship', 'object': ['urn:ngsi-ld:Ravine:006']}, 'controlledProperty': {'type': 'Property', 'value': ['precipitation', 'waterLevel', 'temperature', 'waterFlow']}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}, 'description': {'type': 'Property', 'value': 'Device placed in Ravine 06A06 that flow into Mar Menor'}, 'deviceCategory': {'type': 'Property', 'value': ['sensor']}, 'address': {'type': 'Property', 'value': {'addressCountry': 'ES', 'addressRegion': 'Murcia', 'addressLocality': 'Cabecico del Rey, Murcia', 'postalCode': '30154'}, 'verified': {'type': 'Property', 'value': True}}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12'}, 'location': {'type': 'GeoProperty', 'value': {'type': 'Point', 'coordinates': [37.7541, -1.1443]}}, 'name': {'type': 'Property', 'value': 'Device 043 found in Piezometric Point 06A06'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld'}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1344', 'deviceType': {'type': 'Property', 'value': 'PrecipitationSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'precipitation'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:043'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1344'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'mm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1345', 'deviceType': {'type': 'Property', 'value': 'WaterLevelSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterLevel'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:043'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1345'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1346', 'deviceType': {'type': 'Property', 'value': 'TemperatureSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'temperature'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:043'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1346'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'CEL'}}
# 201
# DeviceMeasurement
# {'id': 'urn:ngsi-ld:DeviceMeasurement:1347', 'deviceType': {'type': 'Property', 'value': 'WaterFlowSensor'}, 'type': 'DeviceMeasurement', 'controlledProperty': {'type': 'Property', 'value': 'waterFlow'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:00:00Z'}, 'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:00:00Z'}, 'refDevice': {'type': 'Relationship', 'object': 'urn:ngsi-ld:Device:043'}, 'source': {'type': 'Property', 'value': 'https://saihweb.chsegura.es/apps/iVisor/visor_variable.php?punto=06A06U12'}, 'name': {'type': 'Property', 'value': 'DeviceMeasurement 1347'}, '@context': 'https://raw.githubusercontent.com/yuye188/MarMenorDT/main/datamodels.context-ngsi.jsonld', 'unit': {'type': 'Property', 'value': 'm3/s'}}
# 201
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2016-01-09T00:05:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2016-01-09T00:05:00Z'}}
# 204

# %% [markdown]
# #### Subimos los historicos al Timescale

# %%
import psycopg2
from datetime import datetime
import uuid
# Conectarse a la base de datos
conn = psycopg2.connect(
    host="localhost",
    port="5432",
    database="orion",
    user="orion",
    password="orion"
)

cursor = conn.cursor()
datos_a_insertar = []

maper_property_controlled = { "Volumen":"volume","Presion":"pressure","Presion Atmosferica":"atmosphericPressure","Direccion del Viento":"windDirection","Velocidad del Viento":"windSpeed","Temperatura": "temperature", "Nivel": "waterLevel", "Pluviometro":"precipitation","Caudal":"waterFlow", "Humedad":"humidity","Conductividad":"conductivity"
}
maper_property_unitcode = { "Volumen":"m3","Presion":"bar", "Presion Atmosferica":"mbar", "Direccion del Viento":"°","Velocidad del Viento":"m/s","Temperatura": "CEL", "Conductividad": "microseconds/cm", "Nivel": "m", "Pluviometro":"mm","Caudal":"m3/s", "Humedad":"%"
}
for carpeta, valorCarpeta in dfs.items():
    id_entity = rambla_entity[carpeta]
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    for index, row in valorCarpeta.iterrows():
        if index == len(valorCarpeta)-1 or index == 0 or index == 1:
            continue
        counters_valorSensor= {}
        for contador,valorSensor in enumerate(sensores):
            if valorSensor == "Date":
                continue
            original = valorSensor
        
            
            measurementPlace = None
            if len(valorSensor.split(" "))>0 and valorSensor not in maper_property_controlled:
                measurementPlace = " ".join(valorSensor.split(" ")[1:])
                valorSensor = valorSensor.split(" ")[0]

            id_device_measurement = link_rambla_sensores[id_entity][valorSensor][measurementPlace]

            fecha_hora = datetime.strptime(row["Date"], "%Y-%m-%dT%H:%M:%SZ")

            value = row[original]
            if math.isnan(row[original]):
                    value = -99

            datos_a_insertar.append(
                (f'urn:ngsi-ld:attributes3:{uuid.uuid4()}', 'https://smartdatamodels.org/dataModel.DeviceMeasurement/numValue', 'Replace', id_device_measurement, fecha_hora, True, maper_property_unitcode[valorSensor], 'None', 'Number', None, None, value, None, None, None, None, None, None, None, None, datetime.now())
            )
            
            if len(datos_a_insertar) > 100000:
                consulta_insercion = f"INSERT INTO attributes VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
                print(f"Insertando {len(datos_a_insertar)} filas en la tabla attributes")
                try:
                    # Ejecutar la consulta para insertar los datos
                    cursor.executemany(consulta_insercion, datos_a_insertar)
                    conn.commit()
                    datos_a_insertar = []
                    print(f"Se han insertado {cursor.rowcount} filas en la tabla attributes")
                except (Exception, psycopg2.DatabaseError) as error:
                    conn.rollback()
                # Confirmar la transacción
                    print(f"Error: {error}")

if len(datos_a_insertar) > 0:
    consulta_insercion = f"INSERT INTO attributes VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
    print(f"Insertando {len(datos_a_insertar)} filas en la tabla attributes")
    try:
        # Ejecutar la consulta para insertar los datos
        cursor.executemany(consulta_insercion, datos_a_insertar)
        conn.commit()
        datos_a_insertar = []
        print(f"Se han insertado {cursor.rowcount} filas en la tabla attributes")
    except (Exception, psycopg2.DatabaseError) as error:
        conn.rollback()
    # Confirmar la transacción
        print(f"Error: {error}")


# Cerrar el cursor y la conexión
cursor.close()
conn.close()
# Out:
# 06A02-Pozo Estrecho
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06P04-La Murta
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06P02-Torre Pacheco
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A05-Fuente Alamo
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06P05-San Javier
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A19-La Marana
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A04-El Estrecho
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A01-La Puebla
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A03-Rbla Albujon
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 01M02-Relojero
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06B01-Elevacion El Albujon
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A18-Desemboc Rbla Albujon
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# 06A06-Los Cegarras
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 100001 filas en la tabla attributes
# Se han insertado 100001 filas en la tabla attributes
# Insertando 75868 filas en la tabla attributes
# Se han insertado 75868 filas en la tabla attributes

# %% [markdown]
# #### Actualizamos el ORION con los ultimos valores

# %%
for carpeta, valorCarpeta in dfs.items():
    ultimos_valores = valorCarpeta.iloc[len(valorCarpeta)-1]
    print(carpeta)
    sensores = list(set( val.split("_")[0] for val in valorCarpeta.columns))
    id_entity = rambla_entity[carpeta]
    for contador,valorSensor in enumerate(sensores):
        if valorSensor == "Date":
            continue
        original = valorSensor
        counters_valorSensor= {}
        
        measurementPlace = None
        if len(valorSensor.split(" "))>0 and valorSensor not in maper_property_controlled:
            measurementPlace = " ".join(valorSensor.split(" ")[1:])
            valorSensor = valorSensor.split(" ")[0]

        if valorSensor not in counters_valorSensor:
            counters_valorSensor[valorSensor] = 0

        id_device_measurement = link_rambla_sensores[id_entity][valorSensor][measurementPlace]
        counters_valorSensor[valorSensor] += 1
        
        modify_entity(
            value=ultimos_valores[original],
            observedAt=ultimos_valores["Date"],
            unitcode=maper_property_unitcode[valorSensor],
            url="http://localhost:1026/ngsi-ld/v1/entities/"+id_device_measurement+"/attrs",
        )
# Out:
# 06A02-Pozo Estrecho
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.1, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06P04-La Murta
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.26, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06P02-Torre Pacheco
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 22.26, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A05-Fuente Alamo
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.1, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06P05-San Javier
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.2, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A19-La Marana
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 19.7, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A04-El Estrecho
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A01-La Puebla
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.182, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.4, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0947, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A03-Rbla Albujon
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 20.6, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 01M02-Relojero
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 1009.5, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mbar'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': -99, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': '°'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 44.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': '%'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 24.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06B01-Elevacion El Albujon
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.46, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 1.77, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'bar'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 4732.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'microseconds/cm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0825, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2.41, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 2698.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A18-Desemboc Rbla Albujon
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.043, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 69.8, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': '%'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 19.9, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.078, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# 06A06-Los Cegarras
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'mm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 21.3, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'CEL'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204
# modify_content
# {'numValue': {'type': 'Property', 'value': 0.0, 'observedAt': '2024-06-09T23:55:00Z', 'unitCode': 'm3/s'}, 'dateLastValueReported': {'type': 'Property', 'value': '2024-06-09T23:55:00Z'}}
# 204

# %% [markdown]
# #### Modificamos la Red Acuatica para añadirle el ID de las Ramblas

# %%
entidades_albujon = ramblas_albujon.values()

value_to_patch = []
for entidad in entidades_albujon:
    patch_content = {
        "type": "Relationship",
        "object": entidad,
    }
    value_to_patch.append(patch_content)
    

modify_entity(
    value=value_to_patch,
    observedAt=None,
    unitcode=None,
    url="http://localhost:1026/ngsi-ld/v1/entities/"+id_water_network+"/attrs",
    isComposedOf=True
)
# Out:
# modify_content
# {'isComposedOf': [{'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:006'}, {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:005'}, {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:004'}, {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:003'}, {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:002'}, {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:007'}, {'type': 'Relationship', 'object': 'urn:ngsi-ld:Ravine:001'}]}
# 204

# %% [markdown]
# #### Añadimos a cada entidad sus entidades cercanas

# %%
entities_id
# Out:
# {'urn:ngsi-ld:Buoy:000': [37.76, -0.78],
#  'urn:ngsi-ld:Buoy:001': [37.68, -0.78],
#  'urn:ngsi-ld:Buoy:002': [37.65, -0.72],
#  'urn:ngsi-ld:Buoy:003': [37.65, -0.78],
#  'urn:ngsi-ld:Buoy:004': [37.66, -0.8],
#  'urn:ngsi-ld:Buoy:005': [37.74, -0.74],
#  'urn:ngsi-ld:Buoy:006': [37.81, -0.78],
#  'urn:ngsi-ld:Buoy:007': [37.71, -0.83],
#  'urn:ngsi-ld:Buoy:008': [37.69, -0.81],
#  'urn:ngsi-ld:Buoy:009': [37.71, -0.77],
#  'urn:ngsi-ld:Buoy:010': [37.74, -0.72],
#  'urn:ngsi-ld:Buoy:011': [37.76, -0.8],
#  'urn:ngsi-ld:SoundingPlace:000': [37.7058, -0.8633],
#  'urn:ngsi-ld:SoundingPlace:001': [37.8181, -0.8286],
#  'urn:ngsi-ld:SoundingPlace:002': [37.7755, -0.8514],
#  'urn:ngsi-ld:SoundingPlace:003': [37.7543, -0.8588],
#  'urn:ngsi-ld:SoundingPlace:004': [37.6841, -0.8692],
#  'urn:ngsi-ld:SoundingPlace:005': [37.7104, -0.8879],
#  'urn:ngsi-ld:SoundingPlace:006': [37.7511, -0.8828],
#  'urn:ngsi-ld:SoundingPlace:007': [37.654261, -0.848734],
#  'urn:ngsi-ld:SoundingPlace:008': [37.7696, -0.8385],
#  'urn:ngsi-ld:SoundingPlace:009': [37.642663, -0.777275],
#  'urn:ngsi-ld:SoundingPlace:010': [37.7452, -0.8679],
#  'urn:ngsi-ld:SoundingPlace:011': [37.7802, -0.8302],
#  'urn:ngsi-ld:SoundingPlace:012': [37.8178, -0.8085],
#  'urn:ngsi-ld:SoundingPlace:013': [37.7618, -0.8673],
#  'urn:ngsi-ld:SoundingPlace:014': [37.8059, -0.8168],
#  'urn:ngsi-ld:SoundingPlace:015': [37.8247, -0.8165],
#  'urn:ngsi-ld:SoundingPlace:016': [37.630082, -0.777017],
#  'urn:ngsi-ld:SoundingPlace:017': [37.7883, -0.8387],
#  'urn:ngsi-ld:SoundingPlace:018': [37.835, -0.8023],
#  'urn:ngsi-ld:Ravine:002': [37.7239, -0.9793],
#  'urn:ngsi-ld:Ravine:010': [37.827, -1.2107],
#  'urn:ngsi-ld:Ravine:009': [37.7492, -0.9921],
#  'urn:ngsi-ld:Ravine:005': [37.7247, -1.1721],
#  'urn:ngsi-ld:Ravine:011': [37.8359, -0.8757],
#  'urn:ngsi-ld:Ravine:008': [37.7953, -0.9415],
#  'urn:ngsi-ld:Ravine:004': [37.7259, -1.1098],
#  'urn:ngsi-ld:Ravine:001': [37.7207, -0.9144],
#  'urn:ngsi-ld:Ravine:003': [37.7213, -1.0491],
#  'urn:ngsi-ld:Ravine:012': [37.9136, -1.119],
#  'urn:ngsi-ld:Ravine:013': [37.7175, -0.8598],
#  'urn:ngsi-ld:Ravine:007': [37.7163, -0.861],
#  'urn:ngsi-ld:Ravine:006': [37.7541, -1.1443]}

# %%
for entity_id, location in entities_id.items():
    close_entities = search_close_entities(location[0], location[1],entity_id)
    print(entity_id)
    create_attribute(
        multipleValue=[{"type":"Relationship","object": close_entity} for close_entity in close_entities],
        value=None,
        observedAt=None,
        url="http://localhost:1026/ngsi-ld/v1/entities/"+entity_id+"/attrs",
        newAttributeName="closeMeasurements"
    )
# Out:
# urn:ngsi-ld:Buoy:000
# urn:ngsi-ld:Buoy:001
# urn:ngsi-ld:Buoy:002
# urn:ngsi-ld:Buoy:003
# urn:ngsi-ld:Buoy:004
# urn:ngsi-ld:Buoy:005
# urn:ngsi-ld:Buoy:006
# urn:ngsi-ld:Buoy:007
# urn:ngsi-ld:Buoy:008
# urn:ngsi-ld:Buoy:009
# urn:ngsi-ld:Buoy:010
# urn:ngsi-ld:Buoy:011
# urn:ngsi-ld:SoundingPlace:000
# urn:ngsi-ld:SoundingPlace:001
# urn:ngsi-ld:SoundingPlace:002
# urn:ngsi-ld:SoundingPlace:003
# urn:ngsi-ld:SoundingPlace:004
# urn:ngsi-ld:SoundingPlace:005
# urn:ngsi-ld:SoundingPlace:006
# urn:ngsi-ld:SoundingPlace:007
# urn:ngsi-ld:SoundingPlace:008
# urn:ngsi-ld:SoundingPlace:009
# urn:ngsi-ld:SoundingPlace:010
# urn:ngsi-ld:SoundingPlace:011
# urn:ngsi-ld:SoundingPlace:012
# urn:ngsi-ld:SoundingPlace:013
# urn:ngsi-ld:SoundingPlace:014
# urn:ngsi-ld:SoundingPlace:015
# urn:ngsi-ld:SoundingPlace:016
# urn:ngsi-ld:SoundingPlace:017
# urn:ngsi-ld:SoundingPlace:018
# urn:ngsi-ld:Ravine:002
# urn:ngsi-ld:Ravine:010
# urn:ngsi-ld:Ravine:009
# urn:ngsi-ld:Ravine:005
# urn:ngsi-ld:Ravine:011
# urn:ngsi-ld:Ravine:008
# urn:ngsi-ld:Ravine:004
# urn:ngsi-ld:Ravine:001
# urn:ngsi-ld:Ravine:003
# urn:ngsi-ld:Ravine:012
# urn:ngsi-ld:Ravine:013
# urn:ngsi-ld:Ravine:007
# urn:ngsi-ld:Ravine:006
